# %% [markdown]
# # Launching WES workflow on DRS objects based on a Data Connect query

# %% [markdown]
# ## Check if endpoints are available

# %% [markdown]
# 1) Check if WES endpoints are available

# %%
import requests
import json

def pretty_print_json(response):
    # pretty print JSON in blue color
    print("\033[38;2;8;75;138m"+json.dumps(response.json(), indent=4)+"\033[0m")
    
def print_head(text):
    # print in green color
    print("\033[38;2;8;138;75m"+text+"\033[0m")

# %%
node_ips = ['ga4gh-starter-kit.ilifu.ac.za','154.114.10.54','154.114.10.62']
wes_port = "6000"
service_info_path = "/service-info"
runs_path = "/runs"
http_method = "GET"

for node_ip in node_ips:
    ga4gh_base_url = "http://" + node_ip + ":{}/ga4gh/{}/v1"
    wes_base_url = ga4gh_base_url.format(wes_port,"wes")
    request_url = wes_base_url+service_info_path
    print_head("{} request to {}".format(http_method, request_url))
    # GET request to service-info endpoint
    wes_service_info_resp = requests.request(http_method, request_url)
    # print the response
    pretty_print_json(wes_service_info_resp)
# Out:
# GET request to http://ga4gh-starter-kit.ilifu.ac.za:6000/ga4gh/wes/v1/service-info
# {
#     "id": "org.ga4gh.starterkit.wes",
#     "name": "GA4GH Starter Kit WES Service",
#     "description": "An open source, community-driven implementation of the GA4GH Workflow Execution Service (WES)API specification.",
#     "contactUrl": "mailto:info@ga4gh.org",
#     "documentationUrl": "https://github.com/ga4gh/ga4gh-starter-kit-wes",
#     "createdAt": "2020-01-15T12:00:00Z",
#     "updatedAt": "2020-01-15T12:00:00Z",
#     "environment": "test",
#     "version": "0.3.2",
#     "type": {
#         "group": "org.ga4gh",
#         "artifact": "wes",
#         "version": "1.0.1"
#     },
#     "organization": {
#         "name": "Global Alliance for Genomics and Health",
#         "url": "https://ga4gh.org"
#     },
#     "workflow_type_versions": {
#         "WDL": [
#             "1.0"
#         ],
#         "NEXTFLOW": [
#             "21.04.0"
#         ]
#     },
#     "workflow_engine_versions": {
#         "NATIVE": "1.0.0"
#     }
# }
# GET request to http://154.114.10.54:6000/ga4gh/wes/v1/service-info
# {
#     "id": "org.ga4gh.starterkit.wes",
#     "name": "GA4GH Starter Kit WES Service",
#     "description": "An open source, community-driven implementation of the GA4GH Workflow Execution Service (WES)API specification.",
#     "contactUrl": "mailto:info@ga4gh.org",
#     "documentationUrl": "https://github.com/ga4gh/ga4gh-starter-kit-wes",
#     "createdAt": "2020-01-15T12:00:00Z",
#     "updatedAt": "2020-01-15T12:00:00Z",
#     "environment": "test",
#     "version": "0.3.2",
#     "type": {
#         "group": "org.ga4gh",
#         "artifact": "wes",
#         "version": "1.0.1"
#     },
#     "organization": {
#         "name": "Global Alliance for Genomics and Health",
#         "url": "https://ga4gh.org"
#     },
#     "workflow_type_versions": {
#         "WDL": [
#             "1.0"
#         ],
#         "NEXTFLOW": [
#             "21.04.0"
#         ]
#     },
#     "workflow_engine_versions": {
#         "NATIVE": "1.0.0"
#     }
# }
# GET request to http://154.114.10.62:6000/ga4gh/wes/v1/service-info
# {
#     "id": "org.ga4gh.starterkit.wes",
#     "name": "GA4GH Starter Kit WES Service",
#     "description": "An open source, community-driven implementation of the GA4GH Workflow Execution Service (WES)API specification.",
#     "contactUrl": "mailto:info@ga4gh.org",
#     "documentationUrl": "https://github.com/ga4gh/ga4gh-starter-kit-wes",
#     "createdAt": "2020-01-15T12:00:00Z",
#     "updatedAt": "2020-01-15T12:00:00Z",
#     "environment": "test",
#     "version": "0.3.2",
#     "type": {
#         "group": "org.ga4gh",
#         "artifact": "wes",
#         "version": "1.0.1"
#     },
#     "organization": {
#         "name": "Global Alliance for Genomics and Health",
#         "url": "https://ga4gh.org"
#     },
#     "workflow_type_versions": {
#         "WDL": [
#             "1.0"
#         ],
#         "NEXTFLOW": [
#             "21.04.0"
#         ]
#     },
#     "workflow_engine_versions": {
#         "NATIVE": "1.0.0"
#     }
# }

# %% [markdown]
# 2) Check if DRS endpoints are available

# %%
node_ips = ['ga4gh-starter-kit.ilifu.ac.za','154.114.10.54','154.114.10.62']
drs_port = "5000"
service_info_path = "/service-info"
http_method = "GET"

for node_ip in node_ips:
    ga4gh_base_url = "http://" + node_ip + ":{}/ga4gh/{}/v1"
    drs_base_url = ga4gh_base_url.format(drs_port,"drs")
    request_url = drs_base_url+service_info_path
    print_head("{} request to {}".format(http_method, request_url))
    # GET request to service-info endpoint
    drs_service_info_resp = requests.request(http_method, request_url)
    # print the response
    pretty_print_json(drs_service_info_resp)
# Out:
# GET request to http://ga4gh-starter-kit.ilifu.ac.za:5000/ga4gh/drs/v1/service-info
# {
#     "id": "org.ga4gh.starterkit.drs",
#     "name": "GA4GH Starter Kit DRS Service",
#     "description": "An open source, community-driven implementation of the GA4GH Data Repository Service (DRS) API specification.",
#     "contactUrl": "mailto:info@ga4gh.org",
#     "documentationUrl": "https://github.com/ga4gh/ga4gh-starter-kit-drs",
#     "createdAt": "2020-01-15T12:00:00Z",
#     "updatedAt": "2020-01-15T12:00:00Z",
#     "environment": "test",
#     "version": "0.3.2",
#     "type": {
#         "group": "org.ga4gh",
#         "artifact": "drs",
#         "version": "1.3.0experimental"
#     },
#     "organization": {
#         "name": "Global Alliance for Genomics and Health",
#         "url": "https://ga4gh.org"
#     }
# }
# GET request to http://154.114.10.54:5000/ga4gh/drs/v1/service-info
# {
#     "id": "org.ga4gh.starterkit.drs",
#     "name": "GA4GH Starter Kit DRS Service",
#     "description": "An open source, community-driven implementation of the GA4GH Data Repository Service (DRS) API specification.",
#     "contactUrl": "mailto:info@ga4gh.org",
#     "documentationUrl": "https://github.com/ga4gh/ga4gh-starter-kit-drs",
#     "createdAt": "2020-01-15T12:00:00Z",
#     "updatedAt": "2020-01-15T12:00:00Z",
#     "environment": "test",
#     "version": "0.3.2",
#     "type": {
#         "group": "org.ga4gh",
#         "artifact": "drs",
#         "version": "1.3.0experimental"
#     },
#     "organization": {
#         "name": "Global Alliance for Genomics and Health",
#         "url": "https://ga4gh.org"
#     }
# }
# GET request to http://154.114.10.62:5000/ga4gh/drs/v1/service-info
# {
#     "id": "org.ga4gh.starterkit.drs",
#     "name": "GA4GH Starter Kit DRS Service",
#     "description": "An open source, community-driven implementation of the GA4GH Data Repository Service (DRS) API specification.",
#     "contactUrl": "mailto:info@ga4gh.org",
#     "documentationUrl": "https://github.com/ga4gh/ga4gh-starter-kit-drs",
#     "createdAt": "2020-01-15T12:00:00Z",
#     "updatedAt": "2020-01-15T12:00:00Z",
#     "environment": "test",
#     "version": "0.3.2",
#     "type": {
#         "group": "org.ga4gh",
#         "artifact": "drs",
#         "version": "1.3.0experimental"
#     },
#     "organization": {
#         "name": "Global Alliance for Genomics and Health",
#         "url": "https://ga4gh.org"
#     }
# }

# %% [markdown]
# ## Check if DRS objects exists on endpoint

# %% [markdown]
# 1. Check ga4gh-starter-kit.ilifu.ac.za

# %%
http_method = "GET"
node_ip = 'ga4gh-starter-kit.ilifu.ac.za'
drs_port = "5000"
drs_ids = ['c542689dba1e54669335c8e25abe6207','5a436bec951fab59dd975bcd10f316f1']
object_path_get = "/objects/{}"
object_path_post = "/objects"
access_path = "/objects/{}/access/{}"

for drs_id in drs_ids:
    ga4gh_base_url = "http://" + node_ip + ":{}/ga4gh/{}/v1"
    drs_base_url = ga4gh_base_url.format(drs_port,"drs")
    request_url = drs_base_url+object_path_get.format(drs_id)
    print_head("{} request to {}".format(http_method, request_url))
    # GET request to /objects/{object_id} endpoint
    drs_object_response = requests.request(http_method, request_url)
    # print the response
    pretty_print_json(drs_object_response)
# Out:
# GET request to http://ga4gh-starter-kit.ilifu.ac.za:5000/ga4gh/drs/v1/objects/c542689dba1e54669335c8e25abe6207
# {
#     "id": "c542689dba1e54669335c8e25abe6207",
#     "description": "Patient: HG01857, Country: KHV, Region: EAS, Sex: female\n",
#     "created_time": "2023-07-24T13:45:58Z",
#     "mime_type": "application/cram",
#     "name": "HG01857.final.chrX_15494566-15607236",
#     "size": 500309,
#     "updated_time": "2023-07-24T13:45:58Z",
#     "checksums": [
#         {
#             "checksum": "70ef6da9822aecf071acda427a61e31cbbf8f25b",
#             "type": "sha1"
#         },
#         {
#             "checksum": "b9e9f9a1f85de2ee57ba05d3f75de865458c2645284e42deef20de38b9e6a37c",
#             "type": "sha256"
#         },
#         {
#             "checksum": "c542689dba1e54669335c8e25abe6207",
#             "type": "md5"
#         }
#     ],
#     "self_uri": "drs://ga4gh-starter-kit.ilifu.ac.za:5000/c542689dba1e54669335c8e25abe6207",
#     "access_methods": [
#         {
#             "access_url": {
#                 "url": "file:///share/elwazi/crams/HG01857/HG01857.final.chrX_15494566-15607236.cram"
#             },
#             "type": "file"
#         },
#         {
#             "access_id": "fd786c22-6d40-4bec-a5af-e763204affe0",
#             "type": "https"
#         }
#     ]
# }
# GET request to http://ga4gh-starter-kit.ilifu.ac.za:5000/ga4gh/drs/v1/objects/5a436bec951fab59dd975bcd10f316f1
# {
#     "id": "5a436bec951fab59dd975bcd10f316f1",
#     "description": "Patient: HG01883, Country: ACB, Region: AFR, Sex: female\n",
#     "created_time": "2023-07-24T13:45:58Z",
#     "mime_type": "application/cram",
#     "name": "HG01883.final.chrX_15494566-15607236",
#     "size": 513233,
#     "updated_time": "2023-07-24T13:45:58Z",
#     "checksums": [
#         {
#             "checksum": "789133eb2d6c421fd0fb753f9cbf8093788f5f25",
#             "type": "sha1"
#         },
#         {
#             "checksum": "0ee02c1db461b8d41381c65aba46ed72777d86ed4cd4ea6982dc5f974aabeb2f",
#             "type": "sha256"
#         },
#         {
#             "checksum": "5a436bec951fab59dd975bcd10f316f1",
#             "type": "md5"
#         }
#     ],
#     "self_uri": "drs://ga4gh-starter-kit.ilifu.ac.za:5000/5a436bec951fab59dd975bcd10f316f1",
#     "access_methods": [
#         {
#             "access_url": {
#                 "url": "file:///share/elwazi/crams/HG01883/HG01883.final.chrX_15494566-15607236.cram"
#             },
#             "type": "file"
#         },
#         {
#             "access_id": "373647a9-55c0-48e1-a598-44366c88d615",
#             "type": "https"
#         }
#     ]
# }

# %% [markdown]
# 2. Check 154.114.10.54 (Uganda)

# %%
http_method = "GET"
node_ip = '154.114.10.54'
drs_port = "5000"
drs_ids = ['6fa43c7de04b60c1a73a42aa2efc977d','be145a60bc059c154475a2561af0df6b']
object_path_get = "/objects/{}"
object_path_post = "/objects"
access_path = "/objects/{}/access/{}"

for drs_id in drs_ids:
    ga4gh_base_url = "http://" + node_ip + ":{}/ga4gh/{}/v1"
    drs_base_url = ga4gh_base_url.format(drs_port,"drs")
    request_url = drs_base_url+object_path_get.format(drs_id)
    print_head("{} request to {}".format(http_method, request_url))
    # GET request to /objects/{object_id} endpoint
    drs_object_response = requests.request(http_method, request_url)
    # print the response
    pretty_print_json(drs_object_response)
# Out:
# GET request to http://154.114.10.54:5000/ga4gh/drs/v1/objects/6fa43c7de04b60c1a73a42aa2efc977d
# {
#     "id": "6fa43c7de04b60c1a73a42aa2efc977d",
#     "description": "Patient: HG01879, Country: ACB, Region: AFR, Sex: male\n",
#     "created_time": "2023-07-26T13:08:05Z",
#     "mime_type": "application/cram",
#     "name": "HG01879.final.chrX_15494566-15607236",
#     "size": 309197,
#     "updated_time": "2023-07-26T13:08:05Z",
#     "checksums": [
#         {
#             "checksum": "af30841a49bba8733cf1f070ff725dd9cdfc91f1",
#             "type": "sha1"
#         },
#         {
#             "checksum": "a61d4570f6d210220fd14b4f7744df46d6dce61df0da35782b528660def996f1",
#             "type": "sha256"
#         },
#         {
#             "checksum": "6fa43c7de04b60c1a73a42aa2efc977d",
#             "type": "md5"
#         }
#     ],
#     "self_uri": "drs://154.114.10.54:5000/6fa43c7de04b60c1a73a42aa2efc977d",
#     "access_methods": [
#         {
#             "access_url": {
#                 "url": "file:///share/elwazi/crams/HG01879/HG01879.final.chrX_15494566-15607236.cram"
#             },
#             "type": "file"
#         },
#         {
#             "access_id": "5ab72901-a73c-47df-8b11-b5c26e50626c",
#             "type": "https"
#         }
#     ]
# }
# GET request to http://154.114.10.54:5000/ga4gh/drs/v1/objects/be145a60bc059c154475a2561af0df6b
# {
#     "id": "be145a60bc059c154475a2561af0df6b",
#     "description": "Patient: HG01885, Country: ACB, Region: AFR, Sex: male\n",
#     "created_time": "2023-07-26T13:08:05Z",
#     "mime_type": "application/cram",
#     "name": "HG01885.final.chrX_15494566-15607236",
#     "size": 317183,
#     "updated_time": "2023-07-26T13:08:05Z",
#     "checksums": [
#         {
#             "checksum": "43594b1eb5e0119242897b9177a234bab9607459",
#             "type": "sha1"
#         },
#         {
#             "checksum": "bbda8eadf8373c1d6f9fc131f1084ea8443e1a575d150782a6d9033f2a06b709",
#             "type": "sha256"
#         },
#         {
#             "checksum": "be145a60bc059c154475a2561af0df6b",
#             "type": "md5"
#         }
#     ],
#     "self_uri": "drs://154.114.10.54:5000/be145a60bc059c154475a2561af0df6b",
#     "access_methods": [
#         {
#             "access_url": {
#                 "url": "file:///share/elwazi/crams/HG01885/HG01885.final.chrX_15494566-15607236.cram"
#             },
#             "type": "file"
#         },
#         {
#             "access_id": "8bbc81b5-f4f6-4b53-9424-12cbea0d5f94",
#             "type": "https"
#         }
#     ]
# }

# %% [markdown]
# 3. Check 154.114.10.62 (Mali)

# %%
http_method = "GET"
node_ip = '154.114.10.62'
drs_port = "5000"
drs_ids = ['a68c60133f942881983d0e15827bf88f','168d353c6f474ca72e35e9209f921a59']
object_path_get = "/objects/{}"
object_path_post = "/objects"
access_path = "/objects/{}/access/{}"

for drs_id in drs_ids:
    ga4gh_base_url = "http://" + node_ip + ":{}/ga4gh/{}/v1"
    drs_base_url = ga4gh_base_url.format(drs_port,"drs")
    request_url = drs_base_url+object_path_get.format(drs_id)
    print_head("{} request to {}".format(http_method, request_url))
    # GET request to /objects/{object_id} endpoint
    drs_object_response = requests.request(http_method, request_url)
    # print the response
    pretty_print_json(drs_object_response)
# Out:
# GET request to http://154.114.10.62:5000/ga4gh/drs/v1/objects/a68c60133f942881983d0e15827bf88f
# {
#     "id": "a68c60133f942881983d0e15827bf88f",
#     "description": "Patient: HG01880, Country: ACB, Region: AFR, Sex: female\n",
#     "created_time": "2023-07-26T12:59:15Z",
#     "mime_type": "application/cram",
#     "name": "HG01880.final.chrX_15494566-15607236",
#     "size": 449026,
#     "updated_time": "2023-07-26T12:59:15Z",
#     "checksums": [
#         {
#             "checksum": "5747e183e64f2fe4d87da568fd30d0159086d1fd",
#             "type": "sha1"
#         },
#         {
#             "checksum": "50284d24e63c3c859f1e3d46a8aa54869e82f6fb37099926f2968fe7e64c15d7",
#             "type": "sha256"
#         },
#         {
#             "checksum": "a68c60133f942881983d0e15827bf88f",
#             "type": "md5"
#         }
#     ],
#     "self_uri": "drs://154.114.10.62:5000/a68c60133f942881983d0e15827bf88f",
#     "access_methods": [
#         {
#             "access_url": {
#                 "url": "file:///share/elwazi/crams/HG01880/HG01880.final.chrX_15494566-15607236.cram"
#             },
#             "type": "file"
#         },
#         {
#             "access_id": "c27cf541-8947-4459-be85-80c2ee096a58",
#             "type": "https"
#         }
#     ]
# }
# GET request to http://154.114.10.62:5000/ga4gh/drs/v1/objects/168d353c6f474ca72e35e9209f921a59
# {
#     "id": "168d353c6f474ca72e35e9209f921a59",
#     "description": "Patient: HG01890, Country: ACB, Region: AFR, Sex: male\n",
#     "created_time": "2023-07-26T12:59:15Z",
#     "mime_type": "application/cram",
#     "name": "HG01890.final.chrX_15494566-15607236",
#     "size": 311698,
#     "updated_time": "2023-07-26T12:59:15Z",
#     "checksums": [
#         {
#             "checksum": "d1ed97df457f1fc8fa5cf5fd2ecd0b1fa6560996",
#             "type": "sha1"
#         },
#         {
#             "checksum": "cba436e789297b20b642be7d1cf6a4363d9694019f907a0d41de4a239b543f5c",
#             "type": "sha256"
#         },
#         {
#             "checksum": "168d353c6f474ca72e35e9209f921a59",
#             "type": "md5"
#         }
#     ],
#     "self_uri": "drs://154.114.10.62:5000/168d353c6f474ca72e35e9209f921a59",
#     "access_methods": [
#         {
#             "access_url": {
#                 "url": "file:///share/elwazi/crams/HG01890/HG01890.final.chrX_15494566-15607236.cram"
#             },
#             "type": "file"
#         },
#         {
#             "access_id": "7ed96ab6-09ca-42de-b58a-a3c8741fbf22",
#             "type": "https"
#         }
#     ]
# }

# %% [markdown]
# ## Launch workflow on test DRS objects from South-Africa, Mali and Uganda (using WES on ga4gh-starter-kit.ilifu.ac.za, 154.114.10.54 or 154.114.10.62)

# %% [markdown]
# 1. Launch workflow
# - Change the node_ip to run on a different WES endpoint
# - Change the infput_file to run on different DRS objects

# %%
#node_ip = 'ga4gh-starter-kit.ilifu.ac.za'
node_ip = '154.114.10.62'
#node_ip = '154.114.10.54'
wes_port = "6000"
service_info_path = "/service-info"
runs_path = "/runs"
http_method = "GET"
ga4gh_base_url = "http://" + node_ip + ":{}/ga4gh/{}/v1"
wes_base_url = ga4gh_base_url.format(wes_port,"wes")

http_method = "POST"
request_url = wes_base_url + runs_path

nextflow_workflow_url = "https://github.com/grbot/cram-qc"
#input_file = "drs://ga4gh-starter-kit.ilifu.ac.za:5000/c542689dba1e54669335c8e25abe6207 drs://ga4gh-starter-kit.ilifu.ac.za:5000/5a436bec951fab59dd975bcd10f316f1"
#input_file = "drs://154.114.10.62:5000/a68c60133f942881983d0e15827bf88f drs://154.114.10.62:5000/168d353c6f474ca72e35e9209f921a59"
input_file = "drs://ga4gh-starter-kit.ilifu.ac.za:5000/c542689dba1e54669335c8e25abe6207 drs://ga4gh-starter-kit.ilifu.ac.za:5000/5a436bec951fab59dd975bcd10f316f1 drs://154.114.10.54:5000/6fa43c7de04b60c1a73a42aa2efc977d drs://154.114.10.54:5000/be145a60bc059c154475a2561af0df6b drs://154.114.10.62:5000/a68c60133f942881983d0e15827bf88f drs://154.114.10.62:5000/168d353c6f474ca72e35e9209f921a59"


data = {
    'workflow_type': 'NEXTFLOW',
    'workflow_type_version': '21.04.0',
    'workflow_url': nextflow_workflow_url,
    'workflow_params': f'{{"input":"{input_file}"}}'
}

print_head("{} request to {}".format(http_method, request_url))

# Post a Nextflow workflow
wes_post_workflow_response = requests.request(http_method, request_url, data = data)

# print the response
pretty_print_json(wes_post_workflow_response)

current_run_id = wes_post_workflow_response.json()["run_id"]

print_head("run_id = {}".format(current_run_id))
# Out:
# POST request to http://154.114.10.62:6000/ga4gh/wes/v1/runs
# {
#     "run_id": "6ef2c369-3778-40e9-9918-a7fb678fd7aa"
# }
# run_id = 6ef2c369-3778-40e9-9918-a7fb678fd7aa

# %% [markdown]
# 2. Check output

# %%
http_method = "GET"
request_url = wes_base_url + runs_path + "/" + current_run_id

print_head("{} request to {}".format(http_method, request_url))

# Get request to /runs/{run_id}
monitor_run_response = requests.request(http_method, request_url)

# print the response
pretty_print_json(monitor_run_response)
# Out:
# GET request to http://154.114.10.62:6000/ga4gh/wes/v1/runs/6ef2c369-3778-40e9-9918-a7fb678fd7aa
# {
#     "run_id": "6ef2c369-3778-40e9-9918-a7fb678fd7aa",
#     "request": {
#         "workflow_params": {
#             "input": "drs://ga4gh-starter-kit.ilifu.ac.za:5000/c542689dba1e54669335c8e25abe6207 drs://ga4gh-starter-kit.ilifu.ac.za:5000/5a436bec951fab59dd975bcd10f316f1 drs://154.114.10.54:5000/6fa43c7de04b60c1a73a42aa2efc977d drs://154.114.10.54:5000/be145a60bc059c154475a2561af0df6b drs://154.114.10.62:5000/a68c60133f942881983d0e15827bf88f drs://154.114.10.62:5000/168d353c6f474ca72e35e9209f921a59"
#         },
#         "workflow_type": "NEXTFLOW",
#         "workflow_type_version": "21.04.0",
#         "workflow_url": "https://github.com/grbot/cram-qc"
#     },
#     "state": "COMPLETE",
#     "run_log": {
#         "name": "grbot/cram-qc",
#         "cmd": [
#             "#!/bin/bash -ue",
#             "samtools flagstat     -@ 1     HG01883.final.chrX_15494566-15607236.cram > HG01883.final.chrX_15494566-15607236.cram.flagstat",
#             "#!/bin/bash -ue",
#             "samtools flagstat     -@ 1     HG01857.final.chrX_15494566-15607236.cram > HG01857.final.chrX_15494566-15607236.cram.flagstat",
#             "#!/bin/bash -ue",
#             "samtools flagstat     -@ 1     HG01879.final.chrX_15494566-15607236.cram > HG01879.final.chrX_15494566-15607236.cram.flagstat",
#             "#!/bin/bash -ue",
#             "samtools flagstat     -@ 1     HG01885.final.chrX_15494566-15607236.cram > HG01885.final.chrX_15494566-15607236.cram.flagstat",
#             "#!/bin/bash -ue",
#             "samtools flagstat     -@ 1     HG01890.final.chrX_15494566-15607236.cram > HG01890.final.chrX_15494566-15607236.cram.flagstat",
#             "#!/bin/bash -ue",
#             "samtools flagstat     -@ 1     HG01880.final.chrX_15494566-15607236.cram > HG01880.final.chrX_15494566-15607236.cram.flagstat",
#             "#!/bin/bash -ue",
#             "multiqc ."
#         ],
#         "start_time": "2023-07-31T11:03:04Z",
#         "end_time": "2023-07-31T11:03:17Z",
#         "stdout": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/6ef2c369-3778-40e9-9918-a7fb678fd7aa?workdirs=65%2F5c17baf8a1163be0e5f37a287346e5%2Cc6%2F603c85ebb051831827c11a0cc410c4%2Cfb%2F0c76104315859a6c4faec306c31755%2C6b%2F76eb27d1aafd8fc1aead6111db892a%2C14%2F1ae68f373e290ac113552b6c9813e0%2Cd6%2Fc8308ec982132fecb41422c932c690%2C76%2Fd60541faef417fa836316980559395",
#         "stderr": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/6ef2c369-3778-40e9-9918-a7fb678fd7aa?workdirs=65%2F5c17baf8a1163be0e5f37a287346e5%2Cc6%2F603c85ebb051831827c11a0cc410c4%2Cfb%2F0c76104315859a6c4faec306c31755%2C6b%2F76eb27d1aafd8fc1aead6111db892a%2C14%2F1ae68f373e290ac113552b6c9813e0%2Cd6%2Fc8308ec982132fecb41422c932c690%2C76%2Fd60541faef417fa836316980559395",
#         "exit_code": 0
#     },
#     "task_logs": [
#         {
#             "name": "run_flagstat",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools flagstat     -@ 1     HG01883.final.chrX_15494566-15607236.cram > HG01883.final.chrX_15494566-15607236.cram.flagstat"
#             ],
#             "start_time": "2023-07-31T11:03:04Z",
#             "end_time": "2023-07-31T11:03:05Z",
#             "stdout": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/6ef2c369-3778-40e9-9918-a7fb678fd7aa/65/5c17baf8a1163be0e5f37a287346e5",
#             "stderr": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/6ef2c369-3778-40e9-9918-a7fb678fd7aa/65/5c17baf8a1163be0e5f37a287346e5",
#             "exit_code": 0
#         },
#         {
#             "name": "run_flagstat",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools flagstat     -@ 1     HG01857.final.chrX_15494566-15607236.cram > HG01857.final.chrX_15494566-15607236.cram.flagstat"
#             ],
#             "start_time": "2023-07-31T11:03:06Z",
#             "end_time": "2023-07-31T11:03:06Z",
#             "stdout": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/6ef2c369-3778-40e9-9918-a7fb678fd7aa/c6/603c85ebb051831827c11a0cc410c4",
#             "stderr": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/6ef2c369-3778-40e9-9918-a7fb678fd7aa/c6/603c85ebb051831827c11a0cc410c4",
#             "exit_code": 0
#         },
#         {
#             "name": "run_flagstat",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools flagstat     -@ 1     HG01879.final.chrX_15494566-15607236.cram > HG01879.final.chrX_15494566-15607236.cram.flagstat"
#             ],
#             "start_time": "2023-07-31T11:03:07Z",
#             "end_time": "2023-07-31T11:03:07Z",
#             "stdout": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/6ef2c369-3778-40e9-9918-a7fb678fd7aa/fb/0c76104315859a6c4faec306c31755",
#             "stderr": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/6ef2c369-3778-40e9-9918-a7fb678fd7aa/fb/0c76104315859a6c4faec306c31755",
#             "exit_code": 0
#         },
#         {
#             "name": "run_flagstat",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools flagstat     -@ 1     HG01885.final.chrX_15494566-15607236.cram > HG01885.final.chrX_15494566-15607236.cram.flagstat"
#             ],
#             "start_time": "2023-07-31T11:03:07Z",
#             "end_time": "2023-07-31T11:03:08Z",
#             "stdout": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/6ef2c369-3778-40e9-9918-a7fb678fd7aa/6b/76eb27d1aafd8fc1aead6111db892a",
#             "stderr": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/6ef2c369-3778-40e9-9918-a7fb678fd7aa/6b/76eb27d1aafd8fc1aead6111db892a",
#             "exit_code": 0
#         },
#         {
#             "name": "run_flagstat",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools flagstat     -@ 1     HG01890.final.chrX_15494566-15607236.cram > HG01890.final.chrX_15494566-15607236.cram.flagstat"
#             ],
#             "start_time": "2023-07-31T11:03:08Z",
#             "end_time": "2023-07-31T11:03:09Z",
#             "stdout": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/6ef2c369-3778-40e9-9918-a7fb678fd7aa/14/1ae68f373e290ac113552b6c9813e0",
#             "stderr": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/6ef2c369-3778-40e9-9918-a7fb678fd7aa/14/1ae68f373e290ac113552b6c9813e0",
#             "exit_code": 0
#         },
#         {
#             "name": "run_flagstat",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools flagstat     -@ 1     HG01880.final.chrX_15494566-15607236.cram > HG01880.final.chrX_15494566-15607236.cram.flagstat"
#             ],
#             "start_time": "2023-07-31T11:03:09Z",
#             "end_time": "2023-07-31T11:03:10Z",
#             "stdout": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/6ef2c369-3778-40e9-9918-a7fb678fd7aa/d6/c8308ec982132fecb41422c932c690",
#             "stderr": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/6ef2c369-3778-40e9-9918-a7fb678fd7aa/d6/c8308ec982132fecb41422c932c690",
#             "exit_code": 0
#         },
#         {
#             "name": "run_multiqc",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "multiqc ."
#             ],
#             "start_time": "2023-07-31T11:03:10Z",
#             "end_time": "2023-07-31T11:03:17Z",
#             "stdout": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/6ef2c369-3778-40e9-9918-a7fb678fd7aa/76/d60541faef417fa836316980559395",
#             "stderr": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/6ef2c369-3778-40e9-9918-a7fb678fd7aa/76/d60541faef417fa836316980559395",
#             "exit_code": 0
#         }
#     ],
#     "outputs": {
#         "multiqc_data/multiqc_citations.txt": "file:///opt/ga4gh-starter-kit-wes/wes_runs/6e/f2/c3/6ef2c369-3778-40e9-9918-a7fb678fd7aa/work/76/d60541faef417fa836316980559395/multiqc_data/multiqc_citations.txt",
#         "HG01883.final.chrX_15494566-15607236.cram": "file:///opt/ga4gh-starter-kit-wes/wes_runs/6e/f2/c3/6ef2c369-3778-40e9-9918-a7fb678fd7aa/work/65/5c17baf8a1163be0e5f37a287346e5/HG01883.final.chrX_15494566-15607236.cram",
#         "multiqc_data/multiqc_samtools_flagstat.txt": "file:///opt/ga4gh-starter-kit-wes/wes_runs/6e/f2/c3/6ef2c369-3778-40e9-9918-a7fb678fd7aa/work/76/d60541faef417fa836316980559395/multiqc_data/multiqc_samtools_flagstat.txt",
#         "HG01879.final.chrX_15494566-15607236.cram": "file:///opt/ga4gh-starter-kit-wes/wes_runs/6e/f2/c3/6ef2c369-3778-40e9-9918-a7fb678fd7aa/work/fb/0c76104315859a6c4faec306c31755/HG01879.final.chrX_15494566-15607236.cram",
#         "multiqc_data/multiqc_general_stats.txt": "file:///opt/ga4gh-starter-kit-wes/wes_runs/6e/f2/c3/6ef2c369-3778-40e9-9918-a7fb678fd7aa/work/76/d60541faef417fa836316980559395/multiqc_data/multiqc_general_stats.txt",
#         "multiqc_data/multiqc.log": "file:///opt/ga4gh-starter-kit-wes/wes_runs/6e/f2/c3/6ef2c369-3778-40e9-9918-a7fb678fd7aa/work/76/d60541faef417fa836316980559395/multiqc_data/multiqc.log",
#         "HG01880.final.chrX_15494566-15607236.cram": "file:///opt/ga4gh-starter-kit-wes/wes_runs/6e/f2/c3/6ef2c369-3778-40e9-9918-a7fb678fd7aa/work/d6/c8308ec982132fecb41422c932c690/HG01880.final.chrX_15494566-15607236.cram",
#         "HG01890.final.chrX_15494566-15607236.cram.flagstat": "file:///opt/ga4gh-starter-kit-wes/wes_runs/6e/f2/c3/6ef2c369-3778-40e9-9918-a7fb678fd7aa/work/14/1ae68f373e290ac113552b6c9813e0/HG01890.final.chrX_15494566-15607236.cram.flagstat",
#         "HG01880.final.chrX_15494566-15607236.cram.flagstat": "file:///opt/ga4gh-starter-kit-wes/wes_runs/6e/f2/c3/6ef2c369-3778-40e9-9918-a7fb678fd7aa/work/d6/c8308ec982132fecb41422c932c690/HG01880.final.chrX_15494566-15607236.cram.flagstat",
#         "HG01885.final.chrX_15494566-15607236.cram.flagstat": "file:///opt/ga4gh-starter-kit-wes/wes_runs/6e/f2/c3/6ef2c369-3778-40e9-9918-a7fb678fd7aa/work/6b/76eb27d1aafd8fc1aead6111db892a/HG01885.final.chrX_15494566-15607236.cram.flagstat",
#         "multiqc_data/multiqc_sources.txt": "file:///opt/ga4gh-starter-kit-wes/wes_runs/6e/f2/c3/6ef2c369-3778-40e9-9918-a7fb678fd7aa/work/76/d60541faef417fa836316980559395/multiqc_data/multiqc_sources.txt",
#         "HG01857.final.chrX_15494566-15607236.cram.flagstat": "file:///opt/ga4gh-starter-kit-wes/wes_runs/6e/f2/c3/6ef2c369-3778-40e9-9918-a7fb678fd7aa/work/c6/603c85ebb051831827c11a0cc410c4/HG01857.final.chrX_15494566-15607236.cram.flagstat",
#         "multiqc_data/multiqc_data.json": "file:///opt/ga4gh-starter-kit-wes/wes_runs/6e/f2/c3/6ef2c369-3778-40e9-9918-a7fb678fd7aa/work/76/d60541faef417fa836316980559395/multiqc_data/multiqc_data.json",
#         "HG01885.final.chrX_15494566-15607236.cram": "file:///opt/ga4gh-starter-kit-wes/wes_runs/6e/f2/c3/6ef2c369-3778-40e9-9918-a7fb678fd7aa/work/6b/76eb27d1aafd8fc1aead6111db892a/HG01885.final.chrX_15494566-15607236.cram",
#         "HG01883.final.chrX_15494566-15607236.cram.flagstat": "file:///opt/ga4gh-starter-kit-wes/wes_runs/6e/f2/c3/6ef2c369-3778-40e9-9918-a7fb678fd7aa/work/65/5c17baf8a1163be0e5f37a287346e5/HG01883.final.chrX_15494566-15607236.cram.flagstat",
#         "HG01857.final.chrX_15494566-15607236.cram": "file:///opt/ga4gh-starter-kit-wes/wes_runs/6e/f2/c3/6ef2c369-3778-40e9-9918-a7fb678fd7aa/work/c6/603c85ebb051831827c11a0cc410c4/HG01857.final.chrX_15494566-15607236.cram",
#         "multiqc_report.html": "file:///opt/ga4gh-starter-kit-wes/wes_runs/6e/f2/c3/6ef2c369-3778-40e9-9918-a7fb678fd7aa/work/76/d60541faef417fa836316980559395/multiqc_report.html",
#         "HG01879.final.chrX_15494566-15607236.cram.flagstat": "file:///opt/ga4gh-starter-kit-wes/wes_runs/6e/f2/c3/6ef2c369-3778-40e9-9918-a7fb678fd7aa/work/fb/0c76104315859a6c4faec306c31755/HG01879.final.chrX_15494566-15607236.cram.flagstat",
#         "HG01890.final.chrX_15494566-15607236.cram": "file:///opt/ga4gh-starter-kit-wes/wes_runs/6e/f2/c3/6ef2c369-3778-40e9-9918-a7fb678fd7aa/work/14/1ae68f373e290ac113552b6c9813e0/HG01890.final.chrX_15494566-15607236.cram"
#     }
# }

# %% [markdown]
# # Data Connect
# 1. Check service-info

# %%
import requests
import json

dc_port = "8089"
dc_base_url = "http://ga4gh-starter-kit.ilifu.ac.za:{}".format(dc_port)


service_info_path = "/service-info"
tables_path = "/tables"
table_info_path = "/table/{}/info"
table_data_path = "/table/{}/data"
search_path = "/search"

def pretty_print_json(response):
    print(json.dumps(response.json(), indent=4))

# %%
dc_service_info_resp = requests.request("GET", dc_base_url+service_info_path)
pretty_print_json(dc_service_info_resp)
# Out:
# {
#     "id": "",
#     "name": "GA4GH Discovery Search API",
#     "description": "",
#     "documentationUrl": "",
#     "contactUrl": "",
#     "version": ""
# }

# %% [markdown]
# 2. Check data table we will be querying

# %%
dc_service_info_resp = requests.request("GET", dc_base_url+'/table/trino.public.genome_ilifu/info')
pretty_print_json(dc_service_info_resp)
# Out:
# {
#     "name": "trino.public.genome_ilifu",
#     "description": "Automatically generated schema",
#     "data_model": {
#         "$id": "http://ga4gh-starter-kit.ilifu.ac.za:8089/table/trino.public.genome_ilifu/info",
#         "description": "Automatically generated schema",
#         "$schema": "http://json-schema.org/draft-07/schema#",
#         "properties": {
#             "sample_id": {
#                 "format": "varchar",
#                 "type": "string",
#                 "$comment": "varchar"
#             },
#             "population_id": {
#                 "format": "varchar",
#                 "type": "string",
#                 "$comment": "varchar"
#             },
#             "super_population_id": {
#                 "format": "varchar",
#                 "type": "string",
#                 "$comment": "varchar"
#             },
#             "sex": {
#                 "format": "varchar",
#                 "type": "string",
#                 "$comment": "varchar"
#             },
#             "cram_drs_id": {
#                 "format": "varchar",
#                 "type": "string",
#                 "$comment": "varchar"
#             },
#             "crai_drs_id": {
#                 "format": "varchar",
#                 "type": "string",
#                 "$comment": "varchar"
#             }
#         }
#     }
# }

# %% [markdown]
# ### Select address and id functions

# %%
import re

def get_address(s):
    address = s.replace("drs://","")
    address = re.sub(':.*', '', address)
    return address
    
def get_drs_id(s):
    drs_id = re.sub('.*/', '', s)
    return drs_id

# %% [markdown]
# ### Use case 1

# %% [markdown]
# ![Use case 1](use_case_1.png)

# %% [markdown]
# 1. Do query
# Select CRAM DRS ids for all African samples. Limit search to 10 samples for now.

# %%
import requests, json
q2 = {
  "query": "select cram_drs_id from trino.public.genome_ilifu where super_population_id='AFR' limit 10",
  "parameters": []
}
r = requests.post("http://ga4gh-starter-kit.ilifu.ac.za:8089/search", json = q2)
print(json.dumps(r.json(), indent=3))
data = r.json()
# Out:
# {
#    "data": [],
#    "pagination": {
#       "next_page_url": "http://ga4gh-starter-kit.ilifu.ac.za:8089/search/v1/statement/queued/20230731_095003_00003_69yj9/y16c2f4ad18cdc29060397427633e35d2ed7fa9ae/1?queryJobId=20230731_095003_00003_69yj9"
#    }
# }

# %% [markdown]
# 2. Parse through pages to get results

# %%
next_page = data['pagination']['next_page_url']
# print (next_page)

# Poll till we get results
while not 'executing' in next_page:
    dc_service_info_resp = requests.request("GET", next_page)
    data = dc_service_info_resp.json()
    next_page = data['pagination']['next_page_url']
    # print (data)

dc_service_info_resp = requests.request("GET", next_page)
# pretty_print_json(dc_service_info_resp)

data = dc_service_info_resp.json()
next_page = data['pagination']['next_page_url']
dc_service_info_resp = requests.request("GET", next_page)
data = dc_service_info_resp.json()
# pretty_print_json(dc_service_info_resp)

drs_str = ""
drs_ids = []
for i in range(len(data['data'])):
    # print (data['data'][i]['cram_drs_id'])
    drs_ids.append(data['data'][i]['cram_drs_id'])
    drs_str = drs_str + data['data'][i]['cram_drs_id'] + " "

drs_str = drs_str[:-1]

# %% [markdown]
# 3. Map DRS server to DRS objects

# %%
drs_servers = {}
for drs_id in drs_ids:
    address = get_address(drs_id)
    if address not in drs_servers:
        drs_servers[address] = {}
        drs_servers[address]['drs_ids'] = []
        drs_servers[address]['drs_ids'].append(drs_id)
        drs_servers[address]['total_file_size'] = 0
        drs_servers[address]['ingress'] = 0
        drs_servers[address]['run_id'] = 0
        drs_servers[address]['drs_ids_str'] = ""
        drs_servers[address]['outputs'] = {}
    else:
        drs_servers[address]['drs_ids'].append(drs_id)
print (drs_servers)
# Out:
# drs://154.114.10.54:5000/6fa43c7de04b60c1a73a42aa2efc977d drs://154.114.10.62:5000/a68c60133f942881983d0e15827bf88f drs://154.114.10.62:5000/45ca586b0921ffedf6a63679fbaacb68 drs://ga4gh-starter-kit.ilifu.ac.za:5000/5a436bec951fab59dd975bcd10f316f1 drs://154.114.10.54:5000/be145a60bc059c154475a2561af0df6b drs://154.114.10.62:5000/d36019bb63182abad672205a140f7e83 drs://154.114.10.62:5000/b809bb9b81a9583ec67e787b0449e9bd drs://154.114.10.62:5000/168d353c6f474ca72e35e9209f921a59 drs://154.114.10.54:5000/9a45659fe478e5bb39d1dd1b08bd1807 drs://154.114.10.54:5000/82adbcf7cc72c31a86e65d73bf6ef81b
# {'154.114.10.54': {'drs_ids': ['drs://154.114.10.54:5000/6fa43c7de04b60c1a73a42aa2efc977d', 'drs://154.114.10.54:5000/be145a60bc059c154475a2561af0df6b', 'drs://154.114.10.54:5000/9a45659fe478e5bb39d1dd1b08bd1807', 'drs://154.114.10.54:5000/82adbcf7cc72c31a86e65d73bf6ef81b'], 'total_file_size': 0, 'ingress': 0, 'run_id': 0, 'drs_ids_str': '', 'outputs': {}}, '154.114.10.62': {'drs_ids': ['drs://154.114.10.62:5000/a68c60133f942881983d0e15827bf88f', 'drs://154.114.10.62:5000/45ca586b0921ffedf6a63679fbaacb68', 'drs://154.114.10.62:5000/d36019bb63182abad672205a140f7e83', 'drs://154.114.10.62:5000/b809bb9b81a9583ec67e787b0449e9bd', 'drs://154.114.10.62:5000/168d353c6f474ca72e35e9209f921a59'], 'total_file_size': 0, 'ingress': 0, 'run_id': 0, 'drs_ids_str': '', 'outputs': {}}, 'ga4gh-starter-kit.ilifu.ac.za': {'drs_ids': ['drs://ga4gh-starter-kit.ilifu.ac.za:5000/5a436bec951fab59dd975bcd10f316f1'], 'total_file_size': 0, 'ingress': 0, 'run_id': 0, 'drs_ids_str': '', 'outputs': {}}}

# %% [markdown]
# 4. Go through DRS servers, check file size of objects and calculate total file size

# %%
for drs_server in drs_servers:
    http_method = "GET"
    drs_port = "5000"
    object_path_get = "/objects/{}"
    ga4gh_base_url = "http://" + drs_server + ":{}/ga4gh/{}/v1"
    total_file_size = 0;
    for drs_id in drs_servers[drs_server]['drs_ids']:
        drs_base_url = ga4gh_base_url.format(drs_port,"drs")
        request_url = drs_base_url+object_path_get.format(get_drs_id(drs_id))
        # print_head("{} request to {}".format(http_method, request_url))
        drs_object_response = requests.request(http_method, request_url)
        data = drs_object_response.json()
        total_file_size = total_file_size + data['size']
        # pretty_print_json(drs_object_response)
    drs_servers[drs_server]['total_file_size'] = total_file_size

#print (drs_servers)

# %% [markdown]
# 5. Go through DRS servers, calculate ingress

# %%
for drs_server_1 in drs_servers:
    ingress = 0
    for drs_server_2 in drs_servers:
        if drs_server_1 != drs_server_2:
            drs_servers[drs_server_1]['ingress'] = drs_servers[drs_server_1]['ingress'] + drs_servers[drs_server_2]['total_file_size']

# %% [markdown]
# 6. Get endpoint with largest file set in size (not optimising on this info anymore, now on least ingress 7.)

# %%
largest_file_set = 0
drs_server_selected = ""
for drs_server in drs_servers:
    if drs_servers[drs_server]['total_file_size'] > largest_file_set:
        largest_file_set = drs_servers[drs_server]['total_file_size']
        drs_server_selected = drs_server

# %% [markdown]
# 7. Get endpoint with least ingress (least data needs to be transferred)

# %%
least_ingress = 0
drs_server_selected = ""
for drs_server in drs_servers:
    if least_ingress == 0:
        least_ingress = drs_servers[drs_server]['ingress']
        drs_server_selected = drs_server

    if (drs_servers[drs_server]['ingress'] < least_ingress):
        least_ingress = drs_servers[drs_server]['ingress']
        drs_server_selected = drs_server

# %% [markdown]
# 8. Launch workflow with selected DRS objects on endpoint with least ingress (this is actually only working for now because all data is on the same path on all the nodes)

# %%
wes_port = "6000"
ga4gh_base_url = "http://" + drs_server_selected + ":{}/ga4gh/{}/v1"
wes_base_url = ga4gh_base_url.format(wes_port,"wes")

service_info_path = "/service-info"
runs_path = "/runs"

http_method = "POST"
request_url = wes_base_url + runs_path

nextflow_workflow_url = "https://github.com/grbot/cram-qc"
input_file = drs_str

#print (drs_str)

data = {
    'workflow_type': 'NEXTFLOW',
    'workflow_type_version': '21.04.0',
    'workflow_url': nextflow_workflow_url,
    'workflow_params': f'{{"input":"{input_file}"}}'
}

print_head("{} request to {}".format(http_method, request_url))

# Post a Nextflow workflow
wes_post_workflow_response = requests.request(http_method, request_url, data = data)

# print the response
pretty_print_json(wes_post_workflow_response)

current_run_id = wes_post_workflow_response.json()["run_id"]

print_head("run_id = {}".format(current_run_id))
# Out:
# POST request to http://154.114.10.62:6000/ga4gh/wes/v1/runs
# {
#     "run_id": "87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13"
# }
# run_id = 87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13

# %% [markdown]
# 9. Get run ouputs

# %%
import time
# On first run might get the error not able to find ["state"]. This is due to underlying isssue below.
#{
#    "timestamp": "2023-07-27T17:10:08Z",
#    "status_code": 400,
#    "error": "Bad Request",
#    "msg": "Could not load WES run log"
#}
# Just rerun for now and then polling will start

http_method = "GET"
request_url = wes_base_url + runs_path + "/" + current_run_id

print_head("{} request to {}".format(http_method, request_url))

# Get request to /runs/{run_id}
monitor_run_response = requests.request(http_method, request_url)
time.sleep(15) # This delay resolves the issue mentioned above
monitor_run_response = requests.request(http_method, request_url)


# Poll until job is complete
while monitor_run_response.json()["state"]!="COMPLETE":
    print("Current job status: " + monitor_run_response.json()["state"])
    time.sleep(5)
    monitor_run_response = requests.request(http_method, request_url)

print("Job running status: " + monitor_run_response.json()["state"])
pretty_print_json(monitor_run_response)
# Out:
# GET request to http://154.114.10.62:6000/ga4gh/wes/v1/runs/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13
# Job running status: COMPLETE
# {
#     "run_id": "87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13",
#     "request": {
#         "workflow_params": {
#             "input": "drs://154.114.10.54:5000/6fa43c7de04b60c1a73a42aa2efc977d drs://154.114.10.62:5000/a68c60133f942881983d0e15827bf88f drs://154.114.10.62:5000/45ca586b0921ffedf6a63679fbaacb68 drs://ga4gh-starter-kit.ilifu.ac.za:5000/5a436bec951fab59dd975bcd10f316f1 drs://154.114.10.54:5000/be145a60bc059c154475a2561af0df6b drs://154.114.10.62:5000/d36019bb63182abad672205a140f7e83 drs://154.114.10.62:5000/b809bb9b81a9583ec67e787b0449e9bd drs://154.114.10.62:5000/168d353c6f474ca72e35e9209f921a59 drs://154.114.10.54:5000/9a45659fe478e5bb39d1dd1b08bd1807 drs://154.114.10.54:5000/82adbcf7cc72c31a86e65d73bf6ef81b"
#         },
#         "workflow_type": "NEXTFLOW",
#         "workflow_type_version": "21.04.0",
#         "workflow_url": "https://github.com/grbot/cram-qc"
#     },
#     "state": "COMPLETE",
#     "run_log": {
#         "name": "grbot/cram-qc",
#         "cmd": [
#             "#!/bin/bash -ue",
#             "samtools flagstat     -@ 1     HG01880.final.chrX_15494566-15607236.cram > HG01880.final.chrX_15494566-15607236.cram.flagstat",
#             "#!/bin/bash -ue",
#             "samtools flagstat     -@ 1     HG01879.final.chrX_15494566-15607236.cram > HG01879.final.chrX_15494566-15607236.cram.flagstat",
#             "#!/bin/bash -ue",
#             "samtools flagstat     -@ 1     HG01883.final.chrX_15494566-15607236.cram > HG01883.final.chrX_15494566-15607236.cram.flagstat",
#             "#!/bin/bash -ue",
#             "samtools flagstat     -@ 1     HG01885.final.chrX_15494566-15607236.cram > HG01885.final.chrX_15494566-15607236.cram.flagstat",
#             "#!/bin/bash -ue",
#             "samtools flagstat     -@ 1     HG01886.final.chrX_15494566-15607236.cram > HG01886.final.chrX_15494566-15607236.cram.flagstat",
#             "#!/bin/bash -ue",
#             "samtools flagstat     -@ 1     HG01882.final.chrX_15494566-15607236.cram > HG01882.final.chrX_15494566-15607236.cram.flagstat",
#             "#!/bin/bash -ue",
#             "samtools flagstat     -@ 1     HG01890.final.chrX_15494566-15607236.cram > HG01890.final.chrX_15494566-15607236.cram.flagstat",
#             "#!/bin/bash -ue",
#             "samtools flagstat     -@ 1     HG01894.final.chrX_15494566-15607236.cram > HG01894.final.chrX_15494566-15607236.cram.flagstat",
#             "#!/bin/bash -ue",
#             "samtools flagstat     -@ 1     HG01889.final.chrX_15494566-15607236.cram > HG01889.final.chrX_15494566-15607236.cram.flagstat",
#             "#!/bin/bash -ue",
#             "samtools flagstat     -@ 1     HG01896.final.chrX_15494566-15607236.cram > HG01896.final.chrX_15494566-15607236.cram.flagstat",
#             "#!/bin/bash -ue",
#             "multiqc ."
#         ],
#         "start_time": "2023-07-31T11:07:55Z",
#         "end_time": "2023-07-31T11:08:10Z",
#         "stdout": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13?workdirs=ee%2F33b8dc4b95e09962e3bb0e8b5535bd%2C31%2F8a82f52aeeacc26ec5320d7a7485ce%2C6b%2F129c530ec01e74bda67c1a9d121d80%2C64%2F5b280469ff7210e1d0a5917977fb63%2Ce9%2Fba2d57e2bdec79028976465d3c4a89%2C02%2F4ddabb355dc632dc66ba31c6ab8dfa%2Ce4%2F0b3da16bfdf26bfcb8a5ffb661fa14%2C82%2Fb08ef6caab8b1c1c2d22b6d4815686%2Cfa%2F941d1940edc5adde7a0273070e1116%2Ca1%2Faf8a78d33b79e735bac2b9d72e4760%2C6a%2F8e4d50ba57c25ca2ebd749058dca89",
#         "stderr": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13?workdirs=ee%2F33b8dc4b95e09962e3bb0e8b5535bd%2C31%2F8a82f52aeeacc26ec5320d7a7485ce%2C6b%2F129c530ec01e74bda67c1a9d121d80%2C64%2F5b280469ff7210e1d0a5917977fb63%2Ce9%2Fba2d57e2bdec79028976465d3c4a89%2C02%2F4ddabb355dc632dc66ba31c6ab8dfa%2Ce4%2F0b3da16bfdf26bfcb8a5ffb661fa14%2C82%2Fb08ef6caab8b1c1c2d22b6d4815686%2Cfa%2F941d1940edc5adde7a0273070e1116%2Ca1%2Faf8a78d33b79e735bac2b9d72e4760%2C6a%2F8e4d50ba57c25ca2ebd749058dca89",
#         "exit_code": 0
#     },
#     "task_logs": [
#         {
#             "name": "run_flagstat",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools flagstat     -@ 1     HG01880.final.chrX_15494566-15607236.cram > HG01880.final.chrX_15494566-15607236.cram.flagstat"
#             ],
#             "start_time": "2023-07-31T11:07:55Z",
#             "end_time": "2023-07-31T11:07:55Z",
#             "stdout": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/ee/33b8dc4b95e09962e3bb0e8b5535bd",
#             "stderr": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/ee/33b8dc4b95e09962e3bb0e8b5535bd",
#             "exit_code": 0
#         },
#         {
#             "name": "run_flagstat",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools flagstat     -@ 1     HG01879.final.chrX_15494566-15607236.cram > HG01879.final.chrX_15494566-15607236.cram.flagstat"
#             ],
#             "start_time": "2023-07-31T11:07:55Z",
#             "end_time": "2023-07-31T11:07:56Z",
#             "stdout": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/31/8a82f52aeeacc26ec5320d7a7485ce",
#             "stderr": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/31/8a82f52aeeacc26ec5320d7a7485ce",
#             "exit_code": 0
#         },
#         {
#             "name": "run_flagstat",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools flagstat     -@ 1     HG01883.final.chrX_15494566-15607236.cram > HG01883.final.chrX_15494566-15607236.cram.flagstat"
#             ],
#             "start_time": "2023-07-31T11:07:57Z",
#             "end_time": "2023-07-31T11:07:57Z",
#             "stdout": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/6b/129c530ec01e74bda67c1a9d121d80",
#             "stderr": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/6b/129c530ec01e74bda67c1a9d121d80",
#             "exit_code": 0
#         },
#         {
#             "name": "run_flagstat",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools flagstat     -@ 1     HG01885.final.chrX_15494566-15607236.cram > HG01885.final.chrX_15494566-15607236.cram.flagstat"
#             ],
#             "start_time": "2023-07-31T11:07:58Z",
#             "end_time": "2023-07-31T11:07:58Z",
#             "stdout": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/64/5b280469ff7210e1d0a5917977fb63",
#             "stderr": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/64/5b280469ff7210e1d0a5917977fb63",
#             "exit_code": 0
#         },
#         {
#             "name": "run_flagstat",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools flagstat     -@ 1     HG01886.final.chrX_15494566-15607236.cram > HG01886.final.chrX_15494566-15607236.cram.flagstat"
#             ],
#             "start_time": "2023-07-31T11:07:58Z",
#             "end_time": "2023-07-31T11:07:59Z",
#             "stdout": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/e9/ba2d57e2bdec79028976465d3c4a89",
#             "stderr": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/e9/ba2d57e2bdec79028976465d3c4a89",
#             "exit_code": 0
#         },
#         {
#             "name": "run_flagstat",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools flagstat     -@ 1     HG01882.final.chrX_15494566-15607236.cram > HG01882.final.chrX_15494566-15607236.cram.flagstat"
#             ],
#             "start_time": "2023-07-31T11:08:00Z",
#             "end_time": "2023-07-31T11:08:00Z",
#             "stdout": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/02/4ddabb355dc632dc66ba31c6ab8dfa",
#             "stderr": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/02/4ddabb355dc632dc66ba31c6ab8dfa",
#             "exit_code": 0
#         },
#         {
#             "name": "run_flagstat",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools flagstat     -@ 1     HG01890.final.chrX_15494566-15607236.cram > HG01890.final.chrX_15494566-15607236.cram.flagstat"
#             ],
#             "start_time": "2023-07-31T11:08:00Z",
#             "end_time": "2023-07-31T11:08:01Z",
#             "stdout": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/e4/0b3da16bfdf26bfcb8a5ffb661fa14",
#             "stderr": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/e4/0b3da16bfdf26bfcb8a5ffb661fa14",
#             "exit_code": 0
#         },
#         {
#             "name": "run_flagstat",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools flagstat     -@ 1     HG01894.final.chrX_15494566-15607236.cram > HG01894.final.chrX_15494566-15607236.cram.flagstat"
#             ],
#             "start_time": "2023-07-31T11:08:01Z",
#             "end_time": "2023-07-31T11:08:02Z",
#             "stdout": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/82/b08ef6caab8b1c1c2d22b6d4815686",
#             "stderr": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/82/b08ef6caab8b1c1c2d22b6d4815686",
#             "exit_code": 0
#         },
#         {
#             "name": "run_flagstat",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools flagstat     -@ 1     HG01889.final.chrX_15494566-15607236.cram > HG01889.final.chrX_15494566-15607236.cram.flagstat"
#             ],
#             "start_time": "2023-07-31T11:08:02Z",
#             "end_time": "2023-07-31T11:08:03Z",
#             "stdout": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/fa/941d1940edc5adde7a0273070e1116",
#             "stderr": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/fa/941d1940edc5adde7a0273070e1116",
#             "exit_code": 0
#         },
#         {
#             "name": "run_flagstat",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools flagstat     -@ 1     HG01896.final.chrX_15494566-15607236.cram > HG01896.final.chrX_15494566-15607236.cram.flagstat"
#             ],
#             "start_time": "2023-07-31T11:08:03Z",
#             "end_time": "2023-07-31T11:08:03Z",
#             "stdout": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/a1/af8a78d33b79e735bac2b9d72e4760",
#             "stderr": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/a1/af8a78d33b79e735bac2b9d72e4760",
#             "exit_code": 0
#         },
#         {
#             "name": "run_multiqc",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "multiqc ."
#             ],
#             "start_time": "2023-07-31T11:08:04Z",
#             "end_time": "2023-07-31T11:08:10Z",
#             "stdout": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/6a/8e4d50ba57c25ca2ebd749058dca89",
#             "stderr": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/6a/8e4d50ba57c25ca2ebd749058dca89",
#             "exit_code": 0
#         }
#     ],
#     "outputs": {
#         "HG01896.final.chrX_15494566-15607236.cram.flagstat": "file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/a1/af8a78d33b79e735bac2b9d72e4760/HG01896.final.chrX_15494566-15607236.cram.flagstat",
#         "HG01886.final.chrX_15494566-15607236.cram": "file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/e9/ba2d57e2bdec79028976465d3c4a89/HG01886.final.chrX_15494566-15607236.cram",
#         "multiqc_data/multiqc_citations.txt": "file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/6a/8e4d50ba57c25ca2ebd749058dca89/multiqc_data/multiqc_citations.txt",
#         "HG01883.final.chrX_15494566-15607236.cram": "file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/6b/129c530ec01e74bda67c1a9d121d80/HG01883.final.chrX_15494566-15607236.cram",
#         "multiqc_data/multiqc_samtools_flagstat.txt": "file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/6a/8e4d50ba57c25ca2ebd749058dca89/multiqc_data/multiqc_samtools_flagstat.txt",
#         "HG01889.final.chrX_15494566-15607236.cram": "file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/fa/941d1940edc5adde7a0273070e1116/HG01889.final.chrX_15494566-15607236.cram",
#         "HG01880.final.chrX_15494566-15607236.cram.flagstat": "file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/ee/33b8dc4b95e09962e3bb0e8b5535bd/HG01880.final.chrX_15494566-15607236.cram.flagstat",
#         "HG01885.final.chrX_15494566-15607236.cram.flagstat": "file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/64/5b280469ff7210e1d0a5917977fb63/HG01885.final.chrX_15494566-15607236.cram.flagstat",
#         "multiqc_data/multiqc_sources.txt": "file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/6a/8e4d50ba57c25ca2ebd749058dca89/multiqc_data/multiqc_sources.txt",
#         "multiqc_data/multiqc_data.json": "file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/6a/8e4d50ba57c25ca2ebd749058dca89/multiqc_data/multiqc_data.json",
#         "HG01879.final.chrX_15494566-15607236.cram.flagstat": "file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/31/8a82f52aeeacc26ec5320d7a7485ce/HG01879.final.chrX_15494566-15607236.cram.flagstat",
#         "HG01886.final.chrX_15494566-15607236.cram.flagstat": "file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/e9/ba2d57e2bdec79028976465d3c4a89/HG01886.final.chrX_15494566-15607236.cram.flagstat",
#         "HG01890.final.chrX_15494566-15607236.cram": "file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/e4/0b3da16bfdf26bfcb8a5ffb661fa14/HG01890.final.chrX_15494566-15607236.cram",
#         "HG01882.final.chrX_15494566-15607236.cram": "file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/02/4ddabb355dc632dc66ba31c6ab8dfa/HG01882.final.chrX_15494566-15607236.cram",
#         "HG01896.final.chrX_15494566-15607236.cram": "file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/a1/af8a78d33b79e735bac2b9d72e4760/HG01896.final.chrX_15494566-15607236.cram",
#         "HG01894.final.chrX_15494566-15607236.cram.flagstat": "file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/82/b08ef6caab8b1c1c2d22b6d4815686/HG01894.final.chrX_15494566-15607236.cram.flagstat",
#         "HG01882.final.chrX_15494566-15607236.cram.flagstat": "file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/02/4ddabb355dc632dc66ba31c6ab8dfa/HG01882.final.chrX_15494566-15607236.cram.flagstat",
#         "HG01879.final.chrX_15494566-15607236.cram": "file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/31/8a82f52aeeacc26ec5320d7a7485ce/HG01879.final.chrX_15494566-15607236.cram",
#         "multiqc_data/multiqc_general_stats.txt": "file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/6a/8e4d50ba57c25ca2ebd749058dca89/multiqc_data/multiqc_general_stats.txt",
#         "multiqc_data/multiqc.log": "file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/6a/8e4d50ba57c25ca2ebd749058dca89/multiqc_data/multiqc.log",
#         "HG01894.final.chrX_15494566-15607236.cram": "file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/82/b08ef6caab8b1c1c2d22b6d4815686/HG01894.final.chrX_15494566-15607236.cram",
#         "HG01880.final.chrX_15494566-15607236.cram": "file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/ee/33b8dc4b95e09962e3bb0e8b5535bd/HG01880.final.chrX_15494566-15607236.cram",
#         "HG01890.final.chrX_15494566-15607236.cram.flagstat": "file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/e4/0b3da16bfdf26bfcb8a5ffb661fa14/HG01890.final.chrX_15494566-15607236.cram.flagstat",
#         "HG01885.final.chrX_15494566-15607236.cram": "file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/64/5b280469ff7210e1d0a5917977fb63/HG01885.final.chrX_15494566-15607236.cram",
#         "HG01883.final.chrX_15494566-15607236.cram.flagstat": "file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/6b/129c530ec01e74bda67c1a9d121d80/HG01883.final.chrX_15494566-15607236.cram.flagstat",
#         "HG01889.final.chrX_15494566-15607236.cram.flagstat": "file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/fa/941d1940edc5adde7a0273070e1116/HG01889.final.chrX_15494566-15607236.cram.flagstat",
#         "multiqc_report.html": "file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/6a/8e4d50ba57c25ca2ebd749058dca89/multiqc_report.html"
#     }
# }

# %% [markdown]
# 10. Post `multiqc_report.html` to the DRS server

# %%
import importlib
import upload_to_drs
importlib.reload(upload_to_drs)

run_id = monitor_run_response.json()['run_id']
outputs = monitor_run_response.json()["outputs"]

for key in outputs:
    if 'multiqc_report.html' in key:
        print (outputs[key])
        file = outputs[key][7:]
        file_ext = file.split(".")[-1]
        meta_d = upload_to_drs.files_metadata_test(run_id, file, file_ext)
        upload_to_drs.add_file_to_server(meta_d, file_ext, drs_server_selected,'5001') #adds drs object
        drs_id = meta_d[0][3]
# Out:
# file:///opt/ga4gh-starter-kit-wes/wes_runs/87/cf/33/87cf33fc-1cc1-4c17-aeba-f1fc2ebe0e13/work/6a/8e4d50ba57c25ca2ebd749058dca89/multiqc_report.html
# http://154.114.10.62:5001/admin/ga4gh/drs/v1/objects

# %% [markdown]
# 11. Retrieve the results

# %%
import urllib.request

drs_port = 5000

object_path_get = "/objects/{}"
http_method = "GET"
ga4gh_base_url = "http://" + drs_server_selected + ":{}/ga4gh/{}/v1"
drs_base_url = ga4gh_base_url.format(drs_port,"drs")
request_url = drs_base_url + object_path_get.format(drs_id)
#print_head("{} request to {}".format(http_method, request_url))
drs_object_response = requests.request(http_method, request_url)
#pretty_print_json(drs_object_response)
data = drs_object_response.json()
access_url = request_url + "/access/" + (data['access_methods'][1]['access_id'])
#print(access_path)
drs_object_response = requests.request(http_method, access_url)
download_url = drs_object_response.json()["url"]
print(download_url)
urllib.request.urlretrieve(download_url, "multiqc_report.html")
# Out:
# http://154.114.10.62:5000/ga4gh/drs/v1/stream/51f94f95c2e3b85bea590f3076f92bfc/cc23ef5f-b9e5-426f-9827-b8b30a2dd037
# ('multiqc_report.html', <http.client.HTTPMessage at 0x7fdd1aab2b60>)

# %% [markdown]
# ### Use case 2
# ### Now we initiate a run in a gather/scatter/federated manner
# #### - Runs are initiated on individual nodes (calculate flagstat)
# #### - Output is gathered and MultiQC are run on the flagstat results on one WES endpoint

# %% [markdown]
# ![Use case 1](use_case_2.png)

# %% [markdown]
# 1) Launch flagstat runs. Use the dictionary structure generated previously. Launch workflow at WES endpoint on DRS objects only from that endpoint.

# %%
# Populate with drs_ids_str
for drs_server in drs_servers:
    print ("Launching jobs on server: " + drs_server)
    drs_ids = drs_servers[drs_server]['drs_ids']
    drs_ids_str = ""
    for drs_id in drs_ids:
        drs_ids_str = drs_ids_str + drs_id + " "
    drs_ids_str = drs_ids_str[:-1]
    print (drs_ids_str)
    drs_servers[drs_server]['drs_ids_str'] = drs_ids_str

# Launch workflow
for drs_server in drs_servers:
    wes_port = "6000"
    ga4gh_base_url = "http://" + drs_server + ":{}/ga4gh/{}/v1"
    wes_base_url = ga4gh_base_url.format(wes_port,"wes")

    runs_path = "/runs"

    http_method = "POST"
    request_url = wes_base_url + runs_path

    nextflow_workflow_url = "https://github.com/grbot/flagstat"

    input_file = drs_servers[drs_server]['drs_ids_str']
    
    data = {
        'workflow_type': 'NEXTFLOW',
        'workflow_type_version': '21.04.0',
        'workflow_url': nextflow_workflow_url,
        'workflow_params': f'{{"input":"{input_file}"}}'
    }

    print_head("{} request to {}".format(http_method, request_url))

    # Post a Nextflow workflow
    wes_post_workflow_response = requests.request(http_method, request_url, data = data)

    # print the response
    pretty_print_json(wes_post_workflow_response)

    current_run_id = wes_post_workflow_response.json()["run_id"]

    print_head("run_id = {}".format(current_run_id))

    ## We don't launch in parallel for now. Just poll a submitted job and retrieve the results
    http_method = "GET"
    request_url = wes_base_url + runs_path + "/" + current_run_id

    print_head("{} request to {}".format(http_method, request_url))

    # Get request to /runs/{run_id}
    monitor_run_response = requests.request(http_method, request_url) 
    time.sleep(15)
    monitor_run_response = requests.request(http_method, request_url)
    
    # Poll until job is complete

    print(monitor_run_response.json())
    while monitor_run_response.json()["state"] != "COMPLETE":
        print("Current job status: " + monitor_run_response.json()["state"])
        time.sleep(5)
        monitor_run_response = requests.request(http_method, request_url)

    print("Job running status: " + monitor_run_response.json()["state"])
    pretty_print_json(monitor_run_response)

    drs_servers[drs_server]['run_id'] = current_run_id
    drs_servers[drs_server]['outputs'] = monitor_run_response.json()["outputs"]
# Out:
# Launching jobs on server: 154.114.10.54
# drs://154.114.10.54:5000/6fa43c7de04b60c1a73a42aa2efc977d drs://154.114.10.54:5000/be145a60bc059c154475a2561af0df6b drs://154.114.10.54:5000/9a45659fe478e5bb39d1dd1b08bd1807 drs://154.114.10.54:5000/82adbcf7cc72c31a86e65d73bf6ef81b
# Launching jobs on server: 154.114.10.62
# drs://154.114.10.62:5000/a68c60133f942881983d0e15827bf88f drs://154.114.10.62:5000/45ca586b0921ffedf6a63679fbaacb68 drs://154.114.10.62:5000/d36019bb63182abad672205a140f7e83 drs://154.114.10.62:5000/b809bb9b81a9583ec67e787b0449e9bd drs://154.114.10.62:5000/168d353c6f474ca72e35e9209f921a59
# Launching jobs on server: ga4gh-starter-kit.ilifu.ac.za
# drs://ga4gh-starter-kit.ilifu.ac.za:5000/5a436bec951fab59dd975bcd10f316f1
# POST request to http://154.114.10.54:6000/ga4gh/wes/v1/runs
# {
#     "run_id": "a776be25-d14f-40ff-8ce7-dfa6305d688f"
# }
# run_id = a776be25-d14f-40ff-8ce7-dfa6305d688f
# GET request to http://154.114.10.54:6000/ga4gh/wes/v1/runs/a776be25-d14f-40ff-8ce7-dfa6305d688f
# {'run_id': 'a776be25-d14f-40ff-8ce7-dfa6305d688f', 'request': {'workflow_params': {'input': 'drs://154.114.10.54:5000/6fa43c7de04b60c1a73a42aa2efc977d drs://154.114.10.54:5000/be145a60bc059c154475a2561af0df6b drs://154.114.10.54:5000/9a45659fe478e5bb39d1dd1b08bd1807 drs://154.114.10.54:5000/82adbcf7cc72c31a86e65d73bf6ef81b'}, 'workflow_type': 'NEXTFLOW', 'workflow_type_version': '21.04.0', 'workflow_url': 'https://github.com/grbot/flagstat'}, 'state': 'COMPLETE', 'run_log': {'name': 'grbot/flagstat', 'cmd': ['#!/bin/bash -ue', 'samtools flagstat     -@ 1     HG01879.final.chrX_15494566-15607236.cram > HG01879.final.chrX_15494566-15607236.cram.flagstat', '#!/bin/bash -ue', 'samtools flagstat     -@ 1     HG01885.final.chrX_15494566-15607236.cram > HG01885.final.chrX_15494566-15607236.cram.flagstat', '#!/bin/bash -ue', 'samtools flagstat     -@ 1     HG01894.final.chrX_15494566-15607236.cram > HG01894.final.chrX_15494566-15607236.cram.flagstat', '#!/bin/bash -ue', 'samtools flagstat     -@ 1     HG01896.final.chrX_15494566-15607236.cram > HG01896.final.chrX_15494566-15607236.cram.flagstat'], 'start_time': '2023-07-31T11:11:17Z', 'end_time': '2023-07-31T11:11:19Z', 'stdout': 'http://154.114.10.54:6000/ga4gh/wes/v1/logs/nextflow/stdout/a776be25-d14f-40ff-8ce7-dfa6305d688f?workdirs=e4%2F7dcded2c1c857a54a70e9d8e41c7cc%2Cae%2F7ee1c4951c7040d34324a6e418f75a%2Cd9%2F5ecd91c25bbf4a70a511d702190163%2Cb0%2F8497e623f7cc1a60371f44e9bba870', 'stderr': 'http://154.114.10.54:6000/ga4gh/wes/v1/logs/nextflow/stderr/a776be25-d14f-40ff-8ce7-dfa6305d688f?workdirs=e4%2F7dcded2c1c857a54a70e9d8e41c7cc%2Cae%2F7ee1c4951c7040d34324a6e418f75a%2Cd9%2F5ecd91c25bbf4a70a511d702190163%2Cb0%2F8497e623f7cc1a60371f44e9bba870', 'exit_code': 0}, 'task_logs': [{'name': 'run_flagstat', 'cmd': ['#!/bin/bash -ue', 'samtools flagstat     -@ 1     HG01879.final.chrX_15494566-15607236.cram > HG01879.final.chrX_15494566-15607236.cram.flagstat'], 'start_time': '2023-07-31T11:11:17Z', 'end_time': '2023-07-31T11:11:18Z', 'stdout': 'http://154.114.10.54:6000/ga4gh/wes/v1/logs/nextflow/stdout/a776be25-d14f-40ff-8ce7-dfa6305d688f/e4/7dcded2c1c857a54a70e9d8e41c7cc', 'stderr': 'http://154.114.10.54:6000/ga4gh/wes/v1/logs/nextflow/stderr/a776be25-d14f-40ff-8ce7-dfa6305d688f/e4/7dcded2c1c857a54a70e9d8e41c7cc', 'exit_code': 0}, {'name': 'run_flagstat', 'cmd': ['#!/bin/bash -ue', 'samtools flagstat     -@ 1     HG01885.final.chrX_15494566-15607236.cram > HG01885.final.chrX_15494566-15607236.cram.flagstat'], 'start_time': '2023-07-31T11:11:18Z', 'end_time': '2023-07-31T11:11:18Z', 'stdout': 'http://154.114.10.54:6000/ga4gh/wes/v1/logs/nextflow/stdout/a776be25-d14f-40ff-8ce7-dfa6305d688f/ae/7ee1c4951c7040d34324a6e418f75a', 'stderr': 'http://154.114.10.54:6000/ga4gh/wes/v1/logs/nextflow/stderr/a776be25-d14f-40ff-8ce7-dfa6305d688f/ae/7ee1c4951c7040d34324a6e418f75a', 'exit_code': 0}, {'name': 'run_flagstat', 'cmd': ['#!/bin/bash -ue', 'samtools flagstat     -@ 1     HG01894.final.chrX_15494566-15607236.cram > HG01894.final.chrX_15494566-15607236.cram.flagstat'], 'start_time': '2023-07-31T11:11:18Z', 'end_time': '2023-07-31T11:11:19Z', 'stdout': 'http://154.114.10.54:6000/ga4gh/wes/v1/logs/nextflow/stdout/a776be25-d14f-40ff-8ce7-dfa6305d688f/d9/5ecd91c25bbf4a70a511d702190163', 'stderr': 'http://154.114.10.54:6000/ga4gh/wes/v1/logs/nextflow/stderr/a776be25-d14f-40ff-8ce7-dfa6305d688f/d9/5ecd91c25bbf4a70a511d702190163', 'exit_code': 0}, {'name': 'run_flagstat', 'cmd': ['#!/bin/bash -ue', 'samtools flagstat     -@ 1     HG01896.final.chrX_15494566-15607236.cram > HG01896.final.chrX_15494566-15607236.cram.flagstat'], 'start_time': '2023-07-31T11:11:19Z', 'end_time': '2023-07-31T11:11:19Z', 'stdout': 'http://154.114.10.54:6000/ga4gh/wes/v1/logs/nextflow/stdout/a776be25-d14f-40ff-8ce7-dfa6305d688f/b0/8497e623f7cc1a60371f44e9bba870', 'stderr': 'http://154.114.10.54:6000/ga4gh/wes/v1/logs/nextflow/stderr/a776be25-d14f-40ff-8ce7-dfa6305d688f/b0/8497e623f7cc1a60371f44e9bba870', 'exit_code': 0}], 'outp ...
# Job running status: COMPLETE
# {
#     "run_id": "a776be25-d14f-40ff-8ce7-dfa6305d688f",
#     "request": {
#         "workflow_params": {
#             "input": "drs://154.114.10.54:5000/6fa43c7de04b60c1a73a42aa2efc977d drs://154.114.10.54:5000/be145a60bc059c154475a2561af0df6b drs://154.114.10.54:5000/9a45659fe478e5bb39d1dd1b08bd1807 drs://154.114.10.54:5000/82adbcf7cc72c31a86e65d73bf6ef81b"
#         },
#         "workflow_type": "NEXTFLOW",
#         "workflow_type_version": "21.04.0",
#         "workflow_url": "https://github.com/grbot/flagstat"
#     },
#     "state": "COMPLETE",
#     "run_log": {
#         "name": "grbot/flagstat",
#         "cmd": [
#             "#!/bin/bash -ue",
#             "samtools flagstat     -@ 1     HG01879.final.chrX_15494566-15607236.cram > HG01879.final.chrX_15494566-15607236.cram.flagstat",
#             "#!/bin/bash -ue",
#             "samtools flagstat     -@ 1     HG01885.final.chrX_15494566-15607236.cram > HG01885.final.chrX_15494566-15607236.cram.flagstat",
#             "#!/bin/bash -ue",
#             "samtools flagstat     -@ 1     HG01894.final.chrX_15494566-15607236.cram > HG01894.final.chrX_15494566-15607236.cram.flagstat",
#             "#!/bin/bash -ue",
#             "samtools flagstat     -@ 1     HG01896.final.chrX_15494566-15607236.cram > HG01896.final.chrX_15494566-15607236.cram.flagstat"
#         ],
#         "start_time": "2023-07-31T11:11:17Z",
#         "end_time": "2023-07-31T11:11:19Z",
#         "stdout": "http://154.114.10.54:6000/ga4gh/wes/v1/logs/nextflow/stdout/a776be25-d14f-40ff-8ce7-dfa6305d688f?workdirs=e4%2F7dcded2c1c857a54a70e9d8e41c7cc%2Cae%2F7ee1c4951c7040d34324a6e418f75a%2Cd9%2F5ecd91c25bbf4a70a511d702190163%2Cb0%2F8497e623f7cc1a60371f44e9bba870",
#         "stderr": "http://154.114.10.54:6000/ga4gh/wes/v1/logs/nextflow/stderr/a776be25-d14f-40ff-8ce7-dfa6305d688f?workdirs=e4%2F7dcded2c1c857a54a70e9d8e41c7cc%2Cae%2F7ee1c4951c7040d34324a6e418f75a%2Cd9%2F5ecd91c25bbf4a70a511d702190163%2Cb0%2F8497e623f7cc1a60371f44e9bba870",
#         "exit_code": 0
#     },
#     "task_logs": [
#         {
#             "name": "run_flagstat",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools flagstat     -@ 1     HG01879.final.chrX_15494566-15607236.cram > HG01879.final.chrX_15494566-15607236.cram.flagstat"
#             ],
#             "start_time": "2023-07-31T11:11:17Z",
#             "end_time": "2023-07-31T11:11:18Z",
#             "stdout": "http://154.114.10.54:6000/ga4gh/wes/v1/logs/nextflow/stdout/a776be25-d14f-40ff-8ce7-dfa6305d688f/e4/7dcded2c1c857a54a70e9d8e41c7cc",
#             "stderr": "http://154.114.10.54:6000/ga4gh/wes/v1/logs/nextflow/stderr/a776be25-d14f-40ff-8ce7-dfa6305d688f/e4/7dcded2c1c857a54a70e9d8e41c7cc",
#             "exit_code": 0
#         },
#         {
#             "name": "run_flagstat",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools flagstat     -@ 1     HG01885.final.chrX_15494566-15607236.cram > HG01885.final.chrX_15494566-15607236.cram.flagstat"
#             ],
#             "start_time": "2023-07-31T11:11:18Z",
#             "end_time": "2023-07-31T11:11:18Z",
#             "stdout": "http://154.114.10.54:6000/ga4gh/wes/v1/logs/nextflow/stdout/a776be25-d14f-40ff-8ce7-dfa6305d688f/ae/7ee1c4951c7040d34324a6e418f75a",
#             "stderr": "http://154.114.10.54:6000/ga4gh/wes/v1/logs/nextflow/stderr/a776be25-d14f-40ff-8ce7-dfa6305d688f/ae/7ee1c4951c7040d34324a6e418f75a",
#             "exit_code": 0
#         },
#         {
#             "name": "run_flagstat",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools flagstat     -@ 1     HG01894.final.chrX_15494566-15607236.cram > HG01894.final.chrX_15494566-15607236.cram.flagstat"
#             ],
#             "start_time": "2023-07-31T11:11:18Z",
#             "end_time": "2023-07-31T11:11:19Z",
#             "stdout": "http://154.114.10.54:6000/ga4gh/wes/v1/logs/nextflow/stdout/a776be25-d14f-40ff-8ce7-dfa6305d688f/d9/5ecd91c25bbf4a70a511d702190163",
#             "stderr": "http://154.114.10.54:6000/ga4gh/wes/v1/logs/nextflow/stderr/a776be25-d14f-40ff-8ce7-dfa6305d688f/d9/5ecd91c25bbf4a70a511d702190163",
#             "exit_code": 0
#         },
#         {
#             "name": "run_flagstat",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools flagstat     -@ 1     HG01896.final.chrX_15494566-15607236.cram > HG01896.final.chrX_15494566-15607236.cram.flagstat"
#             ],
#             "start_time": "2023-07-31T11:11:19Z",
#             "end_time": "2023-07-31T11:11:19Z",
#             "stdout": "http://154.114.10.54:6000/ga4gh/wes/v1/logs/nextflow/stdout/a776be25-d14f-40ff-8ce7-dfa6305d688f/b0/8497e623f7cc1a60371f44e9bba870",
#             "stderr": "http://154.114.10.54:6000/ga4gh/wes/v1/logs/nextflow/stderr/a776be25-d14f-40ff-8ce7-dfa6305d688f/b0/8497e623f7cc1a60371f44e9bba870",
#             "exit_code": 0
#         }
#     ],
#     "outputs": {
#         "HG01894.final.chrX_15494566-15607236.cram": "file:///opt/ga4gh-starter-kit-wes/wes_runs/a7/76/be/a776be25-d14f-40ff-8ce7-dfa6305d688f/work/d9/5ecd91c25bbf4a70a511d702190163/HG01894.final.chrX_15494566-15607236.cram",
#         "HG01896.final.chrX_15494566-15607236.cram": "file:///opt/ga4gh-starter-kit-wes/wes_runs/a7/76/be/a776be25-d14f-40ff-8ce7-dfa6305d688f/work/b0/8497e623f7cc1a60371f44e9bba870/HG01896.final.chrX_15494566-15607236.cram",
#         "HG01896.final.chrX_15494566-15607236.cram.flagstat": "file:///opt/ga4gh-starter-kit-wes/wes_runs/a7/76/be/a776be25-d14f-40ff-8ce7-dfa6305d688f/work/b0/8497e623f7cc1a60371f44e9bba870/HG01896.final.chrX_15494566-15607236.cram.flagstat",
#         "HG01885.final.chrX_15494566-15607236.cram.flagstat": "file:///opt/ga4gh-starter-kit-wes/wes_runs/a7/76/be/a776be25-d14f-40ff-8ce7-dfa6305d688f/work/ae/7ee1c4951c7040d34324a6e418f75a/HG01885.final.chrX_15494566-15607236.cram.flagstat",
#         "HG01894.final.chrX_15494566-15607236.cram.flagstat": "file:///opt/ga4gh-starter-kit-wes/wes_runs/a7/76/be/a776be25-d14f-40ff-8ce7-dfa6305d688f/work/d9/5ecd91c25bbf4a70a511d702190163/HG01894.final.chrX_15494566-15607236.cram.flagstat",
#         "HG01885.final.chrX_15494566-15607236.cram": "file:///opt/ga4gh-starter-kit-wes/wes_runs/a7/76/be/a776be25-d14f-40ff-8ce7-dfa6305d688f/work/ae/7ee1c4951c7040d34324a6e418f75a/HG01885.final.chrX_15494566-15607236.cram",
#         "HG01879.final.chrX_15494566-15607236.cram": "file:///opt/ga4gh-starter-kit-wes/wes_runs/a7/76/be/a776be25-d14f-40ff-8ce7-dfa6305d688f/work/e4/7dcded2c1c857a54a70e9d8e41c7cc/HG01879.final.chrX_15494566-15607236.cram",
#         "HG01879.final.chrX_15494566-15607236.cram.flagstat": "file:///opt/ga4gh-starter-kit-wes/wes_runs/a7/76/be/a776be25-d14f-40ff-8ce7-dfa6305d688f/work/e4/7dcded2c1c857a54a70e9d8e41c7cc/HG01879.final.chrX_15494566-15607236.cram.flagstat"
#     }
# }
# POST request to http://154.114.10.62:6000/ga4gh/wes/v1/runs
# {
#     "run_id": "3e300cd5-e94f-4150-88c4-3bba8e342d12"
# }
# run_id = 3e300cd5-e94f-4150-88c4-3bba8e342d12
# GET request to http://154.114.10.62:6000/ga4gh/wes/v1/runs/3e300cd5-e94f-4150-88c4-3bba8e342d12
# {'run_id': '3e300cd5-e94f-4150-88c4-3bba8e342d12', 'request': {'workflow_params': {'input': 'drs://154.114.10.62:5000/a68c60133f942881983d0e15827bf88f drs://154.114.10.62:5000/45ca586b0921ffedf6a63679fbaacb68 drs://154.114.10.62:5000/d36019bb63182abad672205a140f7e83 drs://154.114.10.62:5000/b809bb9b81a9583ec67e787b0449e9bd drs://154.114.10.62:5000/168d353c6f474ca72e35e9209f921a59'}, 'workflow_type': 'NEXTFLOW', 'workflow_type_version': '21.04.0', 'workflow_url': 'https://github.com/grbot/flagstat'}, 'state': 'COMPLETE', 'run_log': {'name': 'grbot/flagstat', 'cmd': ['#!/bin/bash -ue', 'samtools flagstat     -@ 1     HG01882.final.chrX_15494566-15607236.cram > HG01882.final.chrX_15494566-15607236.cram.flagstat', '#!/bin/bash -ue', 'samtools flagstat     -@ 1     HG01880.final.chrX_15494566-15607236.cram > HG01880.final.chrX_15494566-15607236.cram.flagstat', '#!/bin/bash -ue', 'samtools flagstat     -@ 1     HG01886.final.chrX_15494566-15607236.cram > HG01886.final.chrX_15494566-15607236.cram.flagstat', '#!/bin/bash -ue', 'samtools flagstat     -@ 1     HG01889.final.chrX_15494566-15607236.cram > HG01889.final.chrX_15494566-15607236.cram.flagstat', '#!/bin/bash -ue', 'samtools flagstat     -@ 1     HG01890.final.chrX_15494566-15607236.cram > HG01890.final.chrX_15494566-15607236.cram.flagstat'], 'start_time': '2023-07-31T11:11:44Z', 'end_time': '2023-07-31T11:11:47Z', 'stdout': 'http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/3e300cd5-e94f-4150-88c4-3bba8e342d12?workdirs=14%2F289d3360486e873defe7ca7ae254d4%2C4d%2Fa5143141322746f0daa08c7efb96eb%2Cf1%2Ffd078af301af14954b7ca94fbb2e9e%2C7a%2F2292bf2ac62c92d0f03c0f78c6db5a%2C8e%2F92c7667099c62c41e65f25d1a5b290', 'stderr': 'http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/3e300cd5-e94f-4150-88c4-3bba8e342d12?workdirs=14%2F289d3360486e873defe7ca7ae254d4%2C4d%2Fa5143141322746f0daa08c7efb96eb%2Cf1%2Ffd078af301af14954b7ca94fbb2e9e%2C7a%2F2292bf2ac62c92d0f03c0f78c6db5a%2C8e%2F92c7667099c62c41e65f25d1a5b290', 'exit_code': 0}, 'task_logs': [{'name': 'run_flagstat', 'cmd': ['#!/bin/bash -ue', 'samtools flagstat     -@ 1     HG01882.final.chrX_15494566-15607236.cram > HG01882.final.chrX_15494566-15607236.cram.flagstat'], 'start_time': '2023-07-31T11:11:44Z', 'end_time': '2023-07-31T11:11:44Z', 'stdout': 'http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/3e300cd5-e94f-4150-88c4-3bba8e342d12/14/289d3360486e873defe7ca7ae254d4', 'stderr': 'http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/3e300cd5-e94f-4150-88c4-3bba8e342d12/14/289d3360486e873defe7ca7ae254d4', 'exit_code': 0}, {'name': 'run_flagstat', 'cmd': ['#!/bin/bash -ue', 'samtools flagstat     -@ 1     HG01880.final.chrX_15494566-15607236.cram > HG01880.final.chrX_15494566-15607236.cram.flagstat'], 'start_time': '2023-07-31T11:11:45Z', 'end_time': '2023-07-31T11:11:45Z', 'stdout': 'http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/3e300cd5-e94f-4150-88c4-3bba8e342d12/4d/a5143141322746f0daa08c7efb96eb', 'stderr': 'http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/3e300cd5-e94f-4150-88c4-3bba8e342d12/4d/a5143141322746f0daa08c7efb96eb', 'exit_code': 0}, {'name': 'run_flagstat', 'cmd': ['#!/bin/bash -ue', 'samtools flagstat     -@ 1     HG01886.final.chrX_15494566-15607236.cram > HG01886.final.chrX_15494566-15607236.cram.flagstat'], 'start_time': '2023-07-31T11:11:45Z', 'end_time': '2023-07-31T11:11:46Z', 'stdout': 'http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/3e300cd5-e94f-4150-88c4-3bba8e342d12/f1/fd078af301af14954b7ca94fbb2e9e', 'stderr': 'http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/3e300cd5-e94f-4150-88c4-3bba8e342d12/f1/fd078af301af14954b7ca94fbb2e9e', 'exit_code': 0}, {'name': 'run_flagstat', 'cmd': ['#!/bin/bash -ue', 'samtools flagstat     -@ 1     HG01889.final.chrX_15494566-15607236.cram > HG01889.final.chrX_15494566-15607236.cram.flagstat'], 'start_time': '2023-07-31T11:11:46Z', 'end_time': '2023-07-31T11:11:47Z', 'stdout': 'http://154.114.10. ...
# Job running status: COMPLETE
# {
#     "run_id": "3e300cd5-e94f-4150-88c4-3bba8e342d12",
#     "request": {
#         "workflow_params": {
#             "input": "drs://154.114.10.62:5000/a68c60133f942881983d0e15827bf88f drs://154.114.10.62:5000/45ca586b0921ffedf6a63679fbaacb68 drs://154.114.10.62:5000/d36019bb63182abad672205a140f7e83 drs://154.114.10.62:5000/b809bb9b81a9583ec67e787b0449e9bd drs://154.114.10.62:5000/168d353c6f474ca72e35e9209f921a59"
#         },
#         "workflow_type": "NEXTFLOW",
#         "workflow_type_version": "21.04.0",
#         "workflow_url": "https://github.com/grbot/flagstat"
#     },
#     "state": "COMPLETE",
#     "run_log": {
#         "name": "grbot/flagstat",
#         "cmd": [
#             "#!/bin/bash -ue",
#             "samtools flagstat     -@ 1     HG01882.final.chrX_15494566-15607236.cram > HG01882.final.chrX_15494566-15607236.cram.flagstat",
#             "#!/bin/bash -ue",
#             "samtools flagstat     -@ 1     HG01880.final.chrX_15494566-15607236.cram > HG01880.final.chrX_15494566-15607236.cram.flagstat",
#             "#!/bin/bash -ue",
#             "samtools flagstat     -@ 1     HG01886.final.chrX_15494566-15607236.cram > HG01886.final.chrX_15494566-15607236.cram.flagstat",
#             "#!/bin/bash -ue",
#             "samtools flagstat     -@ 1     HG01889.final.chrX_15494566-15607236.cram > HG01889.final.chrX_15494566-15607236.cram.flagstat",
#             "#!/bin/bash -ue",
#             "samtools flagstat     -@ 1     HG01890.final.chrX_15494566-15607236.cram > HG01890.final.chrX_15494566-15607236.cram.flagstat"
#         ],
#         "start_time": "2023-07-31T11:11:44Z",
#         "end_time": "2023-07-31T11:11:47Z",
#         "stdout": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/3e300cd5-e94f-4150-88c4-3bba8e342d12?workdirs=14%2F289d3360486e873defe7ca7ae254d4%2C4d%2Fa5143141322746f0daa08c7efb96eb%2Cf1%2Ffd078af301af14954b7ca94fbb2e9e%2C7a%2F2292bf2ac62c92d0f03c0f78c6db5a%2C8e%2F92c7667099c62c41e65f25d1a5b290",
#         "stderr": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/3e300cd5-e94f-4150-88c4-3bba8e342d12?workdirs=14%2F289d3360486e873defe7ca7ae254d4%2C4d%2Fa5143141322746f0daa08c7efb96eb%2Cf1%2Ffd078af301af14954b7ca94fbb2e9e%2C7a%2F2292bf2ac62c92d0f03c0f78c6db5a%2C8e%2F92c7667099c62c41e65f25d1a5b290",
#         "exit_code": 0
#     },
#     "task_logs": [
#         {
#             "name": "run_flagstat",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools flagstat     -@ 1     HG01882.final.chrX_15494566-15607236.cram > HG01882.final.chrX_15494566-15607236.cram.flagstat"
#             ],
#             "start_time": "2023-07-31T11:11:44Z",
#             "end_time": "2023-07-31T11:11:44Z",
#             "stdout": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/3e300cd5-e94f-4150-88c4-3bba8e342d12/14/289d3360486e873defe7ca7ae254d4",
#             "stderr": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/3e300cd5-e94f-4150-88c4-3bba8e342d12/14/289d3360486e873defe7ca7ae254d4",
#             "exit_code": 0
#         },
#         {
#             "name": "run_flagstat",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools flagstat     -@ 1     HG01880.final.chrX_15494566-15607236.cram > HG01880.final.chrX_15494566-15607236.cram.flagstat"
#             ],
#             "start_time": "2023-07-31T11:11:45Z",
#             "end_time": "2023-07-31T11:11:45Z",
#             "stdout": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/3e300cd5-e94f-4150-88c4-3bba8e342d12/4d/a5143141322746f0daa08c7efb96eb",
#             "stderr": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/3e300cd5-e94f-4150-88c4-3bba8e342d12/4d/a5143141322746f0daa08c7efb96eb",
#             "exit_code": 0
#         },
#         {
#             "name": "run_flagstat",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools flagstat     -@ 1     HG01886.final.chrX_15494566-15607236.cram > HG01886.final.chrX_15494566-15607236.cram.flagstat"
#             ],
#             "start_time": "2023-07-31T11:11:45Z",
#             "end_time": "2023-07-31T11:11:46Z",
#             "stdout": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/3e300cd5-e94f-4150-88c4-3bba8e342d12/f1/fd078af301af14954b7ca94fbb2e9e",
#             "stderr": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/3e300cd5-e94f-4150-88c4-3bba8e342d12/f1/fd078af301af14954b7ca94fbb2e9e",
#             "exit_code": 0
#         },
#         {
#             "name": "run_flagstat",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools flagstat     -@ 1     HG01889.final.chrX_15494566-15607236.cram > HG01889.final.chrX_15494566-15607236.cram.flagstat"
#             ],
#             "start_time": "2023-07-31T11:11:46Z",
#             "end_time": "2023-07-31T11:11:47Z",
#             "stdout": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/3e300cd5-e94f-4150-88c4-3bba8e342d12/7a/2292bf2ac62c92d0f03c0f78c6db5a",
#             "stderr": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/3e300cd5-e94f-4150-88c4-3bba8e342d12/7a/2292bf2ac62c92d0f03c0f78c6db5a",
#             "exit_code": 0
#         },
#         {
#             "name": "run_flagstat",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools flagstat     -@ 1     HG01890.final.chrX_15494566-15607236.cram > HG01890.final.chrX_15494566-15607236.cram.flagstat"
#             ],
#             "start_time": "2023-07-31T11:11:47Z",
#             "end_time": "2023-07-31T11:11:47Z",
#             "stdout": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stdout/3e300cd5-e94f-4150-88c4-3bba8e342d12/8e/92c7667099c62c41e65f25d1a5b290",
#             "stderr": "http://154.114.10.62:6000/ga4gh/wes/v1/logs/nextflow/stderr/3e300cd5-e94f-4150-88c4-3bba8e342d12/8e/92c7667099c62c41e65f25d1a5b290",
#             "exit_code": 0
#         }
#     ],
#     "outputs": {
#         "HG01882.final.chrX_15494566-15607236.cram": "file:///opt/ga4gh-starter-kit-wes/wes_runs/3e/30/0c/3e300cd5-e94f-4150-88c4-3bba8e342d12/work/14/289d3360486e873defe7ca7ae254d4/HG01882.final.chrX_15494566-15607236.cram",
#         "HG01880.final.chrX_15494566-15607236.cram": "file:///opt/ga4gh-starter-kit-wes/wes_runs/3e/30/0c/3e300cd5-e94f-4150-88c4-3bba8e342d12/work/4d/a5143141322746f0daa08c7efb96eb/HG01880.final.chrX_15494566-15607236.cram",
#         "HG01880.final.chrX_15494566-15607236.cram.flagstat": "file:///opt/ga4gh-starter-kit-wes/wes_runs/3e/30/0c/3e300cd5-e94f-4150-88c4-3bba8e342d12/work/4d/a5143141322746f0daa08c7efb96eb/HG01880.final.chrX_15494566-15607236.cram.flagstat",
#         "HG01890.final.chrX_15494566-15607236.cram.flagstat": "file:///opt/ga4gh-starter-kit-wes/wes_runs/3e/30/0c/3e300cd5-e94f-4150-88c4-3bba8e342d12/work/8e/92c7667099c62c41e65f25d1a5b290/HG01890.final.chrX_15494566-15607236.cram.flagstat",
#         "HG01886.final.chrX_15494566-15607236.cram": "file:///opt/ga4gh-starter-kit-wes/wes_runs/3e/30/0c/3e300cd5-e94f-4150-88c4-3bba8e342d12/work/f1/fd078af301af14954b7ca94fbb2e9e/HG01886.final.chrX_15494566-15607236.cram",
#         "HG01882.final.chrX_15494566-15607236.cram.flagstat": "file:///opt/ga4gh-starter-kit-wes/wes_runs/3e/30/0c/3e300cd5-e94f-4150-88c4-3bba8e342d12/work/14/289d3360486e873defe7ca7ae254d4/HG01882.final.chrX_15494566-15607236.cram.flagstat",
#         "HG01889.final.chrX_15494566-15607236.cram": "file:///opt/ga4gh-starter-kit-wes/wes_runs/3e/30/0c/3e300cd5-e94f-4150-88c4-3bba8e342d12/work/7a/2292bf2ac62c92d0f03c0f78c6db5a/HG01889.final.chrX_15494566-15607236.cram",
#         "HG01889.final.chrX_15494566-15607236.cram.flagstat": "file:///opt/ga4gh-starter-kit-wes/wes_runs/3e/30/0c/3e300cd5-e94f-4150-88c4-3bba8e342d12/work/7a/2292bf2ac62c92d0f03c0f78c6db5a/HG01889.final.chrX_15494566-15607236.cram.flagstat",
#         "HG01886.final.chrX_15494566-15607236.cram.flagstat": "file:///opt/ga4gh-starter-kit-wes/wes_runs/3e/30/0c/3e300cd5-e94f-4150-88c4-3bba8e342d12/work/f1/fd078af301af14954b7ca94fbb2e9e/HG01886.final.chrX_15494566-15607236.cram.flagstat",
#         "HG01890.final.chrX_15494566-15607236.cram": "file:///opt/ga4gh-starter-kit-wes/wes_runs/3e/30/0c/3e300cd5-e94f-4150-88c4-3bba8e342d12/work/8e/92c7667099c62c41e65f25d1a5b290/HG01890.final.chrX_15494566-15607236.cram"
#     }
# }
# POST request to http://ga4gh-starter-kit.ilifu.ac.za:6000/ga4gh/wes/v1/runs
# {
#     "run_id": "b1d22dbc-aa34-4035-95e9-97da2222dede"
# }
# run_id = b1d22dbc-aa34-4035-95e9-97da2222dede
# GET request to http://ga4gh-starter-kit.ilifu.ac.za:6000/ga4gh/wes/v1/runs/b1d22dbc-aa34-4035-95e9-97da2222dede
# {'run_id': 'b1d22dbc-aa34-4035-95e9-97da2222dede', 'request': {'workflow_params': {'input': 'drs://ga4gh-starter-kit.ilifu.ac.za:5000/5a436bec951fab59dd975bcd10f316f1'}, 'workflow_type': 'NEXTFLOW', 'workflow_type_version': '21.04.0', 'workflow_url': 'https://github.com/grbot/flagstat'}, 'state': 'COMPLETE', 'run_log': {'name': 'grbot/flagstat', 'cmd': ['#!/bin/bash -ue', 'samtools flagstat     -@ 1     HG01883.final.chrX_15494566-15607236.cram > HG01883.final.chrX_15494566-15607236.cram.flagstat'], 'start_time': '2023-07-31T11:12:06Z', 'end_time': '2023-07-31T11:12:06Z', 'stdout': 'http://ga4gh-starter-kit.ilifu.ac.za:6000/ga4gh/wes/v1/logs/nextflow/stdout/b1d22dbc-aa34-4035-95e9-97da2222dede?workdirs=fe%2F010d469c73b99545ac5f05ca397e2a', 'stderr': 'http://ga4gh-starter-kit.ilifu.ac.za:6000/ga4gh/wes/v1/logs/nextflow/stderr/b1d22dbc-aa34-4035-95e9-97da2222dede?workdirs=fe%2F010d469c73b99545ac5f05ca397e2a', 'exit_code': 0}, 'task_logs': [{'name': 'run_flagstat', 'cmd': ['#!/bin/bash -ue', 'samtools flagstat     -@ 1     HG01883.final.chrX_15494566-15607236.cram > HG01883.final.chrX_15494566-15607236.cram.flagstat'], 'start_time': '2023-07-31T11:12:06Z', 'end_time': '2023-07-31T11:12:06Z', 'stdout': 'http://ga4gh-starter-kit.ilifu.ac.za:6000/ga4gh/wes/v1/logs/nextflow/stdout/b1d22dbc-aa34-4035-95e9-97da2222dede/fe/010d469c73b99545ac5f05ca397e2a', 'stderr': 'http://ga4gh-starter-kit.ilifu.ac.za:6000/ga4gh/wes/v1/logs/nextflow/stderr/b1d22dbc-aa34-4035-95e9-97da2222dede/fe/010d469c73b99545ac5f05ca397e2a', 'exit_code': 0}], 'outputs': {'HG01883.final.chrX_15494566-15607236.cram': 'file:///opt/ga4gh-starter-kit-wes/wes_runs/b1/d2/2d/b1d22dbc-aa34-4035-95e9-97da2222dede/work/fe/010d469c73b99545ac5f05ca397e2a/HG01883.final.chrX_15494566-15607236.cram', 'HG01883.final.chrX_15494566-15607236.cram.flagstat': 'file:///opt/ga4gh-starter-kit-wes/wes_runs/b1/d2/2d/b1d22dbc-aa34-4035-95e9-97da2222dede/work/fe/010d469c73b99545ac5f05ca397e2a/HG01883.final.chrX_15494566-15607236.cram.flagstat'}}
# Job running status: COMPLETE
# {
#     "run_id": "b1d22dbc-aa34-4035-95e9-97da2222dede",
#     "request": {
#         "workflow_params": {
#             "input": "drs://ga4gh-starter-kit.ilifu.ac.za:5000/5a436bec951fab59dd975bcd10f316f1"
#         },
#         "workflow_type": "NEXTFLOW",
#         "workflow_type_version": "21.04.0",
#         "workflow_url": "https://github.com/grbot/flagstat"
#     },
#     "state": "COMPLETE",
#     "run_log": {
#         "name": "grbot/flagstat",
#         "cmd": [
#             "#!/bin/bash -ue",
#             "samtools flagstat     -@ 1     HG01883.final.chrX_15494566-15607236.cram > HG01883.final.chrX_15494566-15607236.cram.flagstat"
#         ],
#         "start_time": "2023-07-31T11:12:06Z",
#         "end_time": "2023-07-31T11:12:06Z",
#         "stdout": "http://ga4gh-starter-kit.ilifu.ac.za:6000/ga4gh/wes/v1/logs/nextflow/stdout/b1d22dbc-aa34-4035-95e9-97da2222dede?workdirs=fe%2F010d469c73b99545ac5f05ca397e2a",
#         "stderr": "http://ga4gh-starter-kit.ilifu.ac.za:6000/ga4gh/wes/v1/logs/nextflow/stderr/b1d22dbc-aa34-4035-95e9-97da2222dede?workdirs=fe%2F010d469c73b99545ac5f05ca397e2a",
#         "exit_code": 0
#     },
#     "task_logs": [
#         {
#             "name": "run_flagstat",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools flagstat     -@ 1     HG01883.final.chrX_15494566-15607236.cram > HG01883.final.chrX_15494566-15607236.cram.flagstat"
#             ],
#             "start_time": "2023-07-31T11:12:06Z",
#             "end_time": "2023-07-31T11:12:06Z",
#             "stdout": "http://ga4gh-starter-kit.ilifu.ac.za:6000/ga4gh/wes/v1/logs/nextflow/stdout/b1d22dbc-aa34-4035-95e9-97da2222dede/fe/010d469c73b99545ac5f05ca397e2a",
#             "stderr": "http://ga4gh-starter-kit.ilifu.ac.za:6000/ga4gh/wes/v1/logs/nextflow/stderr/b1d22dbc-aa34-4035-95e9-97da2222dede/fe/010d469c73b99545ac5f05ca397e2a",
#             "exit_code": 0
#         }
#     ],
#     "outputs": {
#         "HG01883.final.chrX_15494566-15607236.cram": "file:///opt/ga4gh-starter-kit-wes/wes_runs/b1/d2/2d/b1d22dbc-aa34-4035-95e9-97da2222dede/work/fe/010d469c73b99545ac5f05ca397e2a/HG01883.final.chrX_15494566-15607236.cram",
#         "HG01883.final.chrX_15494566-15607236.cram.flagstat": "file:///opt/ga4gh-starter-kit-wes/wes_runs/b1/d2/2d/b1d22dbc-aa34-4035-95e9-97da2222dede/work/fe/010d469c73b99545ac5f05ca397e2a/HG01883.final.chrX_15494566-15607236.cram.flagstat"
#     }
# }

# %% [markdown]
# 2. a) Upload results to individual DRS servers and get a list of DRS objects (this will not work need to run 2 b) and explained there)

# %%
importlib.reload(upload_to_drs)

drs_ids_str = ""

for drs_server in drs_servers:

    run_id = drs_servers[drs_server]['run_id']
    outputs = drs_servers[drs_server]["outputs"]

    for key in outputs:
        if '.flagstat' in key:
            file = outputs[key][7:]
            file_ext = file.split(".")[-1]
            print (file)
            meta_d = upload_to_drs.files_metadata_test(run_id, file, file_ext)
            upload_to_drs.add_file_to_server(meta_d, file_ext, drs_server,'5001') #adds drs object
            drs_id = "drs://" + drs_server + ":5000/" + meta_d[0][3]
            drs_ids_str = drs_ids_str + " "  + drs_id
            
drs_ids_str = drs_ids_str[:-1]
# Out:
# /opt/ga4gh-starter-kit-wes/wes_runs/a7/76/be/a776be25-d14f-40ff-8ce7-dfa6305d688f/work/b0/8497e623f7cc1a60371f44e9bba870/HG01896.final.chrX_15494566-15607236.cram.flagstat
# http://154.114.10.54:5001/admin/ga4gh/drs/v1/objects
# /opt/ga4gh-starter-kit-wes/wes_runs/a7/76/be/a776be25-d14f-40ff-8ce7-dfa6305d688f/work/ae/7ee1c4951c7040d34324a6e418f75a/HG01885.final.chrX_15494566-15607236.cram.flagstat
# http://154.114.10.54:5001/admin/ga4gh/drs/v1/objects
# /opt/ga4gh-starter-kit-wes/wes_runs/a7/76/be/a776be25-d14f-40ff-8ce7-dfa6305d688f/work/d9/5ecd91c25bbf4a70a511d702190163/HG01894.final.chrX_15494566-15607236.cram.flagstat
# http://154.114.10.54:5001/admin/ga4gh/drs/v1/objects
# /opt/ga4gh-starter-kit-wes/wes_runs/a7/76/be/a776be25-d14f-40ff-8ce7-dfa6305d688f/work/e4/7dcded2c1c857a54a70e9d8e41c7cc/HG01879.final.chrX_15494566-15607236.cram.flagstat
# http://154.114.10.54:5001/admin/ga4gh/drs/v1/objects
# /opt/ga4gh-starter-kit-wes/wes_runs/3e/30/0c/3e300cd5-e94f-4150-88c4-3bba8e342d12/work/4d/a5143141322746f0daa08c7efb96eb/HG01880.final.chrX_15494566-15607236.cram.flagstat
# http://154.114.10.62:5001/admin/ga4gh/drs/v1/objects
# /opt/ga4gh-starter-kit-wes/wes_runs/3e/30/0c/3e300cd5-e94f-4150-88c4-3bba8e342d12/work/8e/92c7667099c62c41e65f25d1a5b290/HG01890.final.chrX_15494566-15607236.cram.flagstat
# http://154.114.10.62:5001/admin/ga4gh/drs/v1/objects
# /opt/ga4gh-starter-kit-wes/wes_runs/3e/30/0c/3e300cd5-e94f-4150-88c4-3bba8e342d12/work/14/289d3360486e873defe7ca7ae254d4/HG01882.final.chrX_15494566-15607236.cram.flagstat
# http://154.114.10.62:5001/admin/ga4gh/drs/v1/objects
# /opt/ga4gh-starter-kit-wes/wes_runs/3e/30/0c/3e300cd5-e94f-4150-88c4-3bba8e342d12/work/7a/2292bf2ac62c92d0f03c0f78c6db5a/HG01889.final.chrX_15494566-15607236.cram.flagstat
# http://154.114.10.62:5001/admin/ga4gh/drs/v1/objects
# /opt/ga4gh-starter-kit-wes/wes_runs/3e/30/0c/3e300cd5-e94f-4150-88c4-3bba8e342d12/work/f1/fd078af301af14954b7ca94fbb2e9e/HG01886.final.chrX_15494566-15607236.cram.flagstat
# http://154.114.10.62:5001/admin/ga4gh/drs/v1/objects
# /opt/ga4gh-starter-kit-wes/wes_runs/b1/d2/2d/b1d22dbc-aa34-4035-95e9-97da2222dede/work/fe/010d469c73b99545ac5f05ca397e2a/HG01883.final.chrX_15494566-15607236.cram.flagstat
# http://ga4gh-starter-kit.ilifu.ac.za:5001/admin/ga4gh/drs/v1/objects

# %% [markdown]
# 2. b) Upload results to individual DRS servers and get a list of DRS access URLs

# %%
importlib.reload(upload_to_drs)

drs_urls_str = ""

for drs_server in drs_servers:

    run_id = drs_servers[drs_server]['run_id']
    outputs = drs_servers[drs_server]["outputs"]

    for key in outputs:
        if '.flagstat' in key:
            print (key)
            file = outputs[key][7:]
            file_ext = file.split(".")[-1]
            meta_d = upload_to_drs.files_metadata_test(run_id, file, file_ext)
            upload_to_drs.add_file_to_server(meta_d, file_ext, drs_server,'5001') #adds drs object
            drs_id = meta_d[0][3]
            drs_port = 5000
            object_path_get = "/objects/{}"
            http_method = "GET"
            ga4gh_base_url = "http://" + drs_server + ":{}/ga4gh/{}/v1"
            drs_base_url = ga4gh_base_url.format(drs_port,"drs")
            request_url = drs_base_url + object_path_get.format(drs_id)
            #print_head("{} request to {}".format(http_method, request_url))
            drs_object_response = requests.request(http_method, request_url)
            #pretty_print_json(drs_object_response)
            data = drs_object_response.json()
            # We cannot use DRS objects here and need to directly stream. DRS objects only resolve to local path
            # and if path is not on server their would be a failure. The disadvantage of using stream is that you loose
            # the file naming.
            access_url = request_url + "/access/" + (data['access_methods'][1]['access_id'])
            drs_object_response = requests.request(http_method, access_url)
            drs_url = drs_object_response.json()["url"]
            drs_urls_str = drs_urls_str + drs_url + " "
    
drs_urls_str = drs_urls_str[:-1]
# Out:
# HG01896.final.chrX_15494566-15607236.cram.flagstat
# http://154.114.10.54:5001/admin/ga4gh/drs/v1/objects
# HG01885.final.chrX_15494566-15607236.cram.flagstat
# http://154.114.10.54:5001/admin/ga4gh/drs/v1/objects
# HG01894.final.chrX_15494566-15607236.cram.flagstat
# http://154.114.10.54:5001/admin/ga4gh/drs/v1/objects
# HG01879.final.chrX_15494566-15607236.cram.flagstat
# http://154.114.10.54:5001/admin/ga4gh/drs/v1/objects
# HG01880.final.chrX_15494566-15607236.cram.flagstat
# http://154.114.10.62:5001/admin/ga4gh/drs/v1/objects
# HG01890.final.chrX_15494566-15607236.cram.flagstat
# http://154.114.10.62:5001/admin/ga4gh/drs/v1/objects
# HG01882.final.chrX_15494566-15607236.cram.flagstat
# http://154.114.10.62:5001/admin/ga4gh/drs/v1/objects
# HG01889.final.chrX_15494566-15607236.cram.flagstat
# http://154.114.10.62:5001/admin/ga4gh/drs/v1/objects
# HG01886.final.chrX_15494566-15607236.cram.flagstat
# http://154.114.10.62:5001/admin/ga4gh/drs/v1/objects
# HG01883.final.chrX_15494566-15607236.cram.flagstat
# http://ga4gh-starter-kit.ilifu.ac.za:5001/admin/ga4gh/drs/v1/objects

# %% [markdown]
# 3. Launch the workflow that will combine the results

# %%
wes_port = "6000"
drs_server_central = "ga4gh-starter-kit.ilifu.ac.za"
ga4gh_base_url = "http://" + drs_server_central + ":{}/ga4gh/{}/v1"
wes_base_url = ga4gh_base_url.format(wes_port,"wes")

service_info_path = "/service-info"
runs_path = "/runs"

http_method = "POST"
request_url = wes_base_url + runs_path

nextflow_workflow_url = "https://github.com/grbot/multiqc"
input_file = drs_urls_str

#print (drs_str)

data = {
    'workflow_type': 'NEXTFLOW',
    'workflow_type_version': '21.04.0',
    'workflow_url': nextflow_workflow_url,
    'workflow_params': f'{{"input":"{input_file}"}}'
}

print_head("{} request to {}".format(http_method, request_url))

# Post a Nextflow workflow
wes_post_workflow_response = requests.request(http_method, request_url, data = data)

# print the response
pretty_print_json(wes_post_workflow_response)

current_run_id = wes_post_workflow_response.json()["run_id"]

print_head("run_id = {}".format(current_run_id))
# Out:
# POST request to http://ga4gh-starter-kit.ilifu.ac.za:6000/ga4gh/wes/v1/runs
# {
#     "run_id": "c3a499fe-ecfa-4340-8ebe-d126fd15bab8"
# }
# run_id = c3a499fe-ecfa-4340-8ebe-d126fd15bab8

# %% [markdown]
# 4. Poll for results

# %%
import time
# On first run might get the error not able to find ["state"]. This is due to underlying isssue below.
#{
#    "timestamp": "2023-07-27T17:10:08Z",
#    "status_code": 400,
#    "error": "Bad Request",
#    "msg": "Could not load WES run log"
#}
# Just rerun for now and then polling will start

http_method = "GET"
request_url = wes_base_url + runs_path + "/" + current_run_id

print_head("{} request to {}".format(http_method, request_url))

# Get request to /runs/{run_id}
monitor_run_response = requests.request(http_method, request_url)
time.sleep(15) # This delay resolves the issue mentioned above
monitor_run_response = requests.request(http_method, request_url)

print(monitor_run_response)

# Poll until job is complete
while monitor_run_response.json()["state"]!="COMPLETE":
    print("Current job status: " + monitor_run_response.json()["state"])
    time.sleep(5)
    monitor_run_response = requests.request(http_method, request_url)

print("Job running status: " + monitor_run_response.json()["state"])
pretty_print_json(monitor_run_response)
# Out:
# GET request to http://ga4gh-starter-kit.ilifu.ac.za:6000/ga4gh/wes/v1/runs/c3a499fe-ecfa-4340-8ebe-d126fd15bab8
# <Response [200]>
# Job running status: COMPLETE
# {
#     "run_id": "c3a499fe-ecfa-4340-8ebe-d126fd15bab8",
#     "request": {
#         "workflow_params": {
#             "input": "http://154.114.10.54:5000/ga4gh/drs/v1/stream/aa9db3115e60350c8c295ebeedd75898/36ea9e85-59fe-4fcf-b50b-e4246b573244 http://154.114.10.54:5000/ga4gh/drs/v1/stream/7a2d378b7a0f8ac3b68938471c074d49/6bdf4071-76fd-49ae-afa3-529a2269229a http://154.114.10.54:5000/ga4gh/drs/v1/stream/e9e6bc591311b1ccbfb3ed96ada7fda9/f09e543f-15cc-4970-8a37-2f695e13ed0e http://154.114.10.54:5000/ga4gh/drs/v1/stream/3e4d5866f570dd3d78a2b86c3e83169a/b1f49292-4312-48f7-b75d-7ac06e3c66c1 http://154.114.10.62:5000/ga4gh/drs/v1/stream/eb7f2b0fea02a4d7a9f9f0e357d44740/25abb585-f827-413a-b3f0-bba36a331290 http://154.114.10.62:5000/ga4gh/drs/v1/stream/be343b6986696166bceb5f291fb23ec4/30e05669-b077-4f06-b8d2-3034202e16a1 http://154.114.10.62:5000/ga4gh/drs/v1/stream/bc976252b4cd71b91e609f8113338fd0/bf154931-da6e-4958-a614-3e166e7cc876 http://154.114.10.62:5000/ga4gh/drs/v1/stream/28b8a5dad844f1fd149a50c9ef579d2c/6a3f45fa-4cf9-4158-add7-ff5587baf5be http://154.114.10.62:5000/ga4gh/drs/v1/stream/e30add1eeaf200b8f0c1740031054550/362851cd-2323-4d5a-a8c4-007cf181120e http://ga4gh-starter-kit.ilifu.ac.za:5000/ga4gh/drs/v1/stream/4983c8f896470d1510945fb6c315b86a/4eebd5b6-c1b4-4135-94a4-31388dfd323a"
#         },
#         "workflow_type": "NEXTFLOW",
#         "workflow_type_version": "21.04.0",
#         "workflow_url": "https://github.com/grbot/multiqc"
#     },
#     "state": "COMPLETE",
#     "run_log": {
#         "name": "grbot/multiqc",
#         "cmd": [
#             "#!/bin/bash -ue",
#             "multiqc ."
#         ],
#         "start_time": "2023-07-31T11:57:11Z",
#         "end_time": "2023-07-31T11:57:16Z",
#         "stdout": "http://ga4gh-starter-kit.ilifu.ac.za:6000/ga4gh/wes/v1/logs/nextflow/stdout/c3a499fe-ecfa-4340-8ebe-d126fd15bab8?workdirs=ef%2F43e148faa635d4562d9a2f839b8750",
#         "stderr": "http://ga4gh-starter-kit.ilifu.ac.za:6000/ga4gh/wes/v1/logs/nextflow/stderr/c3a499fe-ecfa-4340-8ebe-d126fd15bab8?workdirs=ef%2F43e148faa635d4562d9a2f839b8750",
#         "exit_code": 0
#     },
#     "task_logs": [
#         {
#             "name": "run_multiqc",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "multiqc ."
#             ],
#             "start_time": "2023-07-31T11:57:11Z",
#             "end_time": "2023-07-31T11:57:16Z",
#             "stdout": "http://ga4gh-starter-kit.ilifu.ac.za:6000/ga4gh/wes/v1/logs/nextflow/stdout/c3a499fe-ecfa-4340-8ebe-d126fd15bab8/ef/43e148faa635d4562d9a2f839b8750",
#             "stderr": "http://ga4gh-starter-kit.ilifu.ac.za:6000/ga4gh/wes/v1/logs/nextflow/stderr/c3a499fe-ecfa-4340-8ebe-d126fd15bab8/ef/43e148faa635d4562d9a2f839b8750",
#             "exit_code": 0
#         }
#     ],
#     "outputs": {
#         "multiqc_data/multiqc_citations.txt": "file:///opt/ga4gh-starter-kit-wes/wes_runs/c3/a4/99/c3a499fe-ecfa-4340-8ebe-d126fd15bab8/work/ef/43e148faa635d4562d9a2f839b8750/multiqc_data/multiqc_citations.txt",
#         "6bdf4071-76fd-49ae-afa3-529a2269229a": "file:///opt/ga4gh-starter-kit-wes/wes_runs/c3/a4/99/c3a499fe-ecfa-4340-8ebe-d126fd15bab8/work/ef/43e148faa635d4562d9a2f839b8750/6bdf4071-76fd-49ae-afa3-529a2269229a",
#         "multiqc_data/multiqc_samtools_flagstat.txt": "file:///opt/ga4gh-starter-kit-wes/wes_runs/c3/a4/99/c3a499fe-ecfa-4340-8ebe-d126fd15bab8/work/ef/43e148faa635d4562d9a2f839b8750/multiqc_data/multiqc_samtools_flagstat.txt",
#         "362851cd-2323-4d5a-a8c4-007cf181120e": "file:///opt/ga4gh-starter-kit-wes/wes_runs/c3/a4/99/c3a499fe-ecfa-4340-8ebe-d126fd15bab8/work/ef/43e148faa635d4562d9a2f839b8750/362851cd-2323-4d5a-a8c4-007cf181120e",
#         "6a3f45fa-4cf9-4158-add7-ff5587baf5be": "file:///opt/ga4gh-starter-kit-wes/wes_runs/c3/a4/99/c3a499fe-ecfa-4340-8ebe-d126fd15bab8/work/ef/43e148faa635d4562d9a2f839b8750/6a3f45fa-4cf9-4158-add7-ff5587baf5be",
#         "multiqc_data/multiqc_general_stats.txt": "file:///opt/ga4gh-starter-kit-wes/wes_runs/c3/a4/99/c3a499fe-ecfa-4340-8ebe-d126fd15bab8/work/ef/43e148faa635d4562d9a2f839b8750/multiqc_data/multiqc_general_stats.txt",
#         "multiqc_data/multiqc.log": "file:///opt/ga4gh-starter-kit-wes/wes_runs/c3/a4/99/c3a499fe-ecfa-4340-8ebe-d126fd15bab8/work/ef/43e148faa635d4562d9a2f839b8750/multiqc_data/multiqc.log",
#         "4eebd5b6-c1b4-4135-94a4-31388dfd323a": "file:///opt/ga4gh-starter-kit-wes/wes_runs/c3/a4/99/c3a499fe-ecfa-4340-8ebe-d126fd15bab8/work/ef/43e148faa635d4562d9a2f839b8750/4eebd5b6-c1b4-4135-94a4-31388dfd323a",
#         "36ea9e85-59fe-4fcf-b50b-e4246b573244": "file:///opt/ga4gh-starter-kit-wes/wes_runs/c3/a4/99/c3a499fe-ecfa-4340-8ebe-d126fd15bab8/work/ef/43e148faa635d4562d9a2f839b8750/36ea9e85-59fe-4fcf-b50b-e4246b573244",
#         "25abb585-f827-413a-b3f0-bba36a331290": "file:///opt/ga4gh-starter-kit-wes/wes_runs/c3/a4/99/c3a499fe-ecfa-4340-8ebe-d126fd15bab8/work/ef/43e148faa635d4562d9a2f839b8750/25abb585-f827-413a-b3f0-bba36a331290",
#         "multiqc_data/multiqc_sources.txt": "file:///opt/ga4gh-starter-kit-wes/wes_runs/c3/a4/99/c3a499fe-ecfa-4340-8ebe-d126fd15bab8/work/ef/43e148faa635d4562d9a2f839b8750/multiqc_data/multiqc_sources.txt",
#         "multiqc_data/multiqc_data.json": "file:///opt/ga4gh-starter-kit-wes/wes_runs/c3/a4/99/c3a499fe-ecfa-4340-8ebe-d126fd15bab8/work/ef/43e148faa635d4562d9a2f839b8750/multiqc_data/multiqc_data.json",
#         "bf154931-da6e-4958-a614-3e166e7cc876": "file:///opt/ga4gh-starter-kit-wes/wes_runs/c3/a4/99/c3a499fe-ecfa-4340-8ebe-d126fd15bab8/work/ef/43e148faa635d4562d9a2f839b8750/bf154931-da6e-4958-a614-3e166e7cc876",
#         "f09e543f-15cc-4970-8a37-2f695e13ed0e": "file:///opt/ga4gh-starter-kit-wes/wes_runs/c3/a4/99/c3a499fe-ecfa-4340-8ebe-d126fd15bab8/work/ef/43e148faa635d4562d9a2f839b8750/f09e543f-15cc-4970-8a37-2f695e13ed0e",
#         "30e05669-b077-4f06-b8d2-3034202e16a1": "file:///opt/ga4gh-starter-kit-wes/wes_runs/c3/a4/99/c3a499fe-ecfa-4340-8ebe-d126fd15bab8/work/ef/43e148faa635d4562d9a2f839b8750/30e05669-b077-4f06-b8d2-3034202e16a1",
#         "multiqc_report.html": "file:///opt/ga4gh-starter-kit-wes/wes_runs/c3/a4/99/c3a499fe-ecfa-4340-8ebe-d126fd15bab8/work/ef/43e148faa635d4562d9a2f839b8750/multiqc_report.html",
#         "b1f49292-4312-48f7-b75d-7ac06e3c66c1": "file:///opt/ga4gh-starter-kit-wes/wes_runs/c3/a4/99/c3a499fe-ecfa-4340-8ebe-d126fd15bab8/work/ef/43e148faa635d4562d9a2f839b8750/b1f49292-4312-48f7-b75d-7ac06e3c66c1"
#     }
# }

# %% [markdown]
# 5. Upload `multiqc_report.html` to central DRS server

# %%
import importlib
import upload_to_drs
importlib.reload(upload_to_drs)

run_id = monitor_run_response.json()['run_id']
outputs = monitor_run_response.json()["outputs"]

for key in outputs:
    if 'multiqc_report.html' in key:
        print (outputs[key])
        file = outputs[key][7:]
        file_ext = file.split(".")[-1]
        meta_d = upload_to_drs.files_metadata_test(run_id, file, file_ext)
        upload_to_drs.add_file_to_server(meta_d, file_ext, drs_server_central,'5001') #adds drs object
        drs_id = meta_d[0][3]
# Out:
# file:///opt/ga4gh-starter-kit-wes/wes_runs/c3/a4/99/c3a499fe-ecfa-4340-8ebe-d126fd15bab8/work/ef/43e148faa635d4562d9a2f839b8750/multiqc_report.html
# http://ga4gh-starter-kit.ilifu.ac.za:5001/admin/ga4gh/drs/v1/objects

# %% [markdown]
# 6. Download `multiqc_report.html`

# %%
import urllib.request

drs_port = 5000

object_path_get = "/objects/{}"
http_method = "GET"
ga4gh_base_url = "http://" + drs_server_central + ":{}/ga4gh/{}/v1"
drs_base_url = ga4gh_base_url.format(drs_port,"drs")
request_url = drs_base_url + object_path_get.format(drs_id)
#print_head("{} request to {}".format(http_method, request_url))
drs_object_response = requests.request(http_method, request_url)
#pretty_print_json(drs_object_response)
data = drs_object_response.json()
access_url = request_url + "/access/" + (data['access_methods'][1]['access_id'])
#print(access_path)
drs_object_response = requests.request(http_method, access_url)
download_url = drs_object_response.json()["url"]
print(download_url)
urllib.request.urlretrieve(download_url, "multiqc_report_2.html")
# Out:
# http://ga4gh-starter-kit.ilifu.ac.za:5000/ga4gh/drs/v1/stream/d7dbba132b1a721a8caec07aa768f630/9cfe1861-497d-4984-8453-cd380a9a2d65
# ('multiqc_report_2.html', <http.client.HTTPMessage at 0x7fdd1aab33d0>)
